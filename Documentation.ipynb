# %% [markdown]
# # Documentation for LSTM model for actions recognition

# %% [markdown]
# # 1: Annotation Files
#
# To create the dataset, we first need annotations. Annotations created with **ELAN** can be exported as CSV files using the following steps:
#
# 1. Go to **File** -> **Export As** -> **Tab-delimited Text**.
# 2. Select the desired annotations.
# 3. Export the file, ensuring to choose the CSV format.
#
# Once exported, you should add a header to the CSV file to make reading the various fields easier later on. The following code represents how to prepare annotations for one video.

# %%
# Add a header to a CSV file
import pandas as pd
def add_header(csv_in_path, csv_out_path):
    # Header to add to each annotation
    HEADER = ["Event", "Nan", "Start_time", "Start_seconds", "End_time", "End_seconds", "Duration", "Duration_seconds", "Tools/Speaker"]
    annotations_df = pd.read_csv(csv_in_path)
    # Add the header
    annotations_df.columns = HEADER
    # Overwrite the CSV file with the new header
    annotations_df.to_csv(csv_out_path, index=False)
    # Print the first few rows of the file
    print(annotations_df.head())

path_in = "Annotations_Untitled.csv"
path_out = "Annotations_with_header.csv"
add_header(path_in, path_out)
# Out:
#     Event  Nan    Start_time  Start_seconds      End_time  End_seconds  \
# 0  speech  NaN  00:00:01.347          1.347  00:00:09.667        9.667
# 1  speech  NaN  00:00:11.472         11.472  00:00:15.320       15.320
# 2  speech  NaN  00:00:26.272         26.272  00:00:32.009       32.009
# 3  speech  NaN  00:00:38.135         38.135  00:00:39.147       39.147
# 4  speech  NaN  00:00:56.680         56.680  00:00:58.823       58.823
#
#        Duration  Duration_seconds Tools/Speaker
# 0  00:00:08.320             8.320           NaN
# 1  00:00:03.848             3.848           NaN
# 2  00:00:05.737             5.737           NaN
# 3  00:00:01.012             1.012           NaN
# 4  00:00:02.143             2.143           NaN

# %% [markdown]
# ## 1.1 (Optional): Creating "Speech" and "Other" Annotations
#
# For the purpose of this study, two additional annotations were created:
#
# - **Speech**: To identify when a person is speaking.
# - **Other**: To categorize actions or states not covered by other annotations, helping the model's generalization.
#
# To create these annotations, refer to sections *1.1.1* and *1.1.2*.

# %% [markdown]
# ### 1.1.1 Creating the "Speech" Annotation
#
# To detect and segment speakers in an audio file, the open-source **Speaker Diarization 3.1** model by Pyannote was used. This model enables accurate speaker diarization and segmentation.
#
# The code and detailed instructions for downloading the model and generating the required access token can be found on the official repository:
# [Pyannote-Audio GitHub Repository](https://github.com/pyannote/pyannote-audio).

# %%
# Creating Speech Annotation
# Pyannote Speaker Diarization segments audio based on different speakers
import csv
from datetime import timedelta
from pyannote.audio import Pipeline
import torch

# Function to print speakers from an audio file
def print_speakers(audio_file):
    # Load speaker diarization pipeline
    pipeline = Pipeline.from_pretrained(
        "pyannote/speaker-diarization-3.1", 
        use_auth_token="Pippo") # TODO: Insert token here. To obtain the token, refer to the GitHub link mentioned above.

    # Send pipeline to GPU (when available)
    pipeline.to(torch.device("cuda"))
    diarization = pipeline(audio_file)  

    # Print the results
    print("Speaker Diarization:")
    for turn, _, speaker in diarization.itertracks(yield_label=True):
        print(f"start={turn.start:.1f}s stop={turn.end:.1f}s speaker_{speaker}")
    return diarization

# Run diarization on the audio file and print the speakers
diarization = print_speakers("01.wav")
# Out:
# Speaker Diarization:
# start=0.0s stop=0.1s speaker_SPEAKER_03
# start=0.1s stop=1.0s speaker_SPEAKER_00
# start=1.3s stop=2.6s speaker_SPEAKER_00
# start=1.3s stop=9.7s speaker_SPEAKER_03
# start=3.3s stop=5.5s speaker_SPEAKER_00
# start=10.1s stop=10.1s speaker_SPEAKER_03
# start=10.1s stop=10.2s speaker_SPEAKER_00
# start=10.2s stop=10.4s speaker_SPEAKER_03
# start=10.4s stop=10.9s speaker_SPEAKER_00
# start=10.9s stop=11.0s speaker_SPEAKER_03
# start=11.0s stop=11.5s speaker_SPEAKER_00
# start=11.5s stop=15.3s speaker_SPEAKER_03
# start=11.5s stop=13.2s speaker_SPEAKER_00
# start=14.4s stop=18.0s speaker_SPEAKER_00
# start=18.9s stop=21.1s speaker_SPEAKER_00
# start=21.6s stop=22.1s speaker_SPEAKER_00
# start=21.7s stop=23.9s speaker_SPEAKER_02
# start=24.7s stop=25.0s speaker_SPEAKER_00
# start=25.0s stop=25.5s speaker_SPEAKER_03
# start=25.5s stop=25.9s speaker_SPEAKER_02
# start=25.9s stop=25.9s speaker_SPEAKER_03
# start=25.9s stop=25.9s speaker_SPEAKER_02
# start=26.3s stop=26.3s speaker_SPEAKER_00
# start=26.3s stop=32.0s speaker_SPEAKER_03
# start=27.0s stop=28.1s speaker_SPEAKER_02
# start=32.6s stop=33.3s speaker_SPEAKER_03
# start=33.3s stop=33.3s speaker_SPEAKER_00
# start=33.9s stop=34.4s speaker_SPEAKER_03
# start=34.9s stop=35.5s speaker_SPEAKER_00
# start=35.5s stop=36.3s speaker_SPEAKER_03
# start=38.1s stop=39.1s speaker_SPEAKER_03
# start=41.4s stop=42.2s speaker_SPEAKER_03
# start=42.2s stop=42.2s speaker_SPEAKER_00
# start=45.6s stop=45.6s speaker_SPEAKER_01
# start=45.6s stop=45.7s speaker_SPEAKER_00
# start=45.7s stop=45.8s speaker_SPEAKER_01
# start=45.8s stop=46.0s speaker_SPEAKER_00
# start=46.0s stop=46.1s speaker_SPEAKER_01
# start=47.4s stop=49.0s speaker_SPEAKER_01
# start=47.6s stop=47.6s speaker_SPEAKER_00
# start=50.0s stop=50.9s speaker_SPEAKER_01
# start=50.5s stop=53.9s speaker_SPEAKER_00
# start=56.7s stop=58.8s speaker_SPEAKER_03
# start=59.4s stop=60.8s speaker_SPEAKER_03
# start=61.7s stop=67.0s speaker_SPEAKER_03
# start=62.3s stop=63.0s speaker_SPEAKER_00
# start=63.0s stop=63.0s speaker_SPEAKER_01
# start=63.0s stop=64.7s speaker_SPEAKER_02
# start=67.0s stop=68.7s speaker_SPEAKER_00
# start=69.5s stop=69.6s speaker_SPEAKER_03
# start=69.6s stop=70.9s speaker_SPEAKER_00
# start=74.8s stop=75.8s speaker_SPEAKER_00
# start=77.0s stop=78.3s speaker_SPEAKER_00
# start=79.5s stop=80.8s speaker_SPEAKER_00
# start=81.6s stop=84.5s speaker_SPEAKER_00
# start=84.2s stop=85.3s speaker_SPEAKER_01
# start=85.9s stop=86.8s speaker_SPEAKER_01
# start=87.9s stop=88.8s speaker_SPEAKER_01
# start=89.3s stop=93.8s speaker_SPEAKER_03
# start=94.6s stop=95.2s speaker_SPEAKER_03
# start=95.2s stop=95.5s speaker_SPEAKER_00
# start=95.5s stop=96.0s speaker_SPEAKER_03
# start=96.0s stop=97.7s speaker_SPEAKER_00
# start=99.2s stop=99.3s speaker_SPEAKER_03
# start=99.3s stop=100.4s speaker_SPEAKER_00
# start=99.3s stop=100.1s speaker_SPEAKER_02
# start=100.4s stop=100.5s speaker_SPEAKER_03
# start=100.5s stop=100.7s speaker_SPEAKER_00
# start=100.7s stop=101.1s speaker_SPEAKER_00
# start=101.1s stop=101.1s speaker_SPEAKER_02
# start=103.0s stop=105.8s speaker_SPEAKER_02
# start=106.6s stop=107.0s speaker_SPEAKER_02
# start=107.0s stop=109.7s speaker_SPEAKER_01
# start=109.7s stop=109.8s speaker_SPEAKER_02
# start=110.2s stop=111.9s speaker_SPEAKER_02
# start=114.7s stop=117.5s speaker_SPEAKER_02
# start=117.8s stop=118.4s speaker_SPEAKER_02
# start=119.4s stop=121.4s speaker_SPEAKER_02
# start=123.5s stop=123.5s speaker_SPEAKER_02
# start=123.5s stop=123.8s speaker_SPEAKER_00
# start=124.2s stop=124.3s speaker_SPEAKER_00
# start=125.8s stop=128.7s speaker_SPEAKER_00
# start=129.3s stop=129.6s speaker_SPEAKER_00
# start=130.1s stop=131.0s speaker_SPEAKER_00
# start=131.4s stop=131.9s speaker_SPEAKER_00
# start=132.7s stop=135.5s speaker_SPEAKER_00
# start=136.1s stop=139.4s speaker_SPEAKER_00
# start=138.1s stop=144.7s speaker_SPEAKER_03
# start=145.1s stop=145.9s speaker_SPEAKER_03
# start=147.4s stop=148.6s speaker_SPEAKER_03
# start=147.5s stop=151.2s speaker_SPEAKER_00
# start=152.0s stop=152.9s speaker_SPEAKER_03
# start=152.2s stop=154.7s speaker_SPEAKER_00
# start=154.7s stop=154.9s speaker_SPEAKER_03
# start=154.9s stop=154.9s speaker_SPEAKER_00
# start=154.9s stop=154.9s speaker_SPEAKER_03
# start=156.3s stop=156.3s speaker_SPEAKER_03
# start=156.3s stop=156.4s speaker_SPEAKER_01
# start=156.4s stop=156.5s speaker_SPEAKER_03
# start=156.5s stop=156.6s speaker_SPEAKER_00
# start=157.4s stop=159.5s speaker_SPEAKER_00
# start=157.4s stop=159.0s speaker_SPEAKER_03
# start=161.1s stop=162.2s speaker_SPEAKER_00
# start=162.5s stop=163.5s speaker_SPEAKER_00
# start=162.7s stop=163.0s speaker_SPEAKER_03
# start=163.0s stop=163.3s speaker_SPEAKER_01
# start=163.3s stop=163.4s speaker_SPEAKER_03
# start=163.4s stop=163.5s speaker_SPEAKER_04
# start=165.1s stop=170.6s speaker_SPEAKER_00
# start=169.0s stop=170.4s speaker_SPEAKER_04
# start=172.4s stop=173.9s speaker_SPEAKER_00
# start=174.3s stop=178.9s speaker_SPEAKER_00
# start=180.0s stop=181.1s speaker_SPEAKER_00
# start=180.0s stop=183.9s speaker_SPEAKER_02
# start=184.6s stop=186.1s speaker_SPEAKER_02
# start=186.5s stop=187.7s speaker_SPEAKER_02
# start=190.1s stop=190.7s speaker_SPEAKER_03
# start=191.4s stop=196.4s speaker_SPEAKER_03
# start=196.9s stop=199.8s speaker_SPEAKER_03
# start=199.8s stop=199.8s speaker_SPEAKER_00
# start=201.4s stop=201.6s speaker_SPEAKER_03
# start=201.6s stop=203.8s speaker_SPEAKER_00
# start=205.4s stop=206.9s speaker_SPEAKER_00
# start=206.9s stop=207.0s speaker_SPEAKER_03
# start=207.0s stop=207.0s speaker_SPEAKER_00
# start=207.0s stop=210.5s speaker_SPEAKER_03
# start=209.7s stop=211.0s speaker_SPEAKER_00
# start=211.7s stop=213.2s speaker_SPEAKER_03
# start=212.8s stop=217.1s speaker_SPEAKER_00
# start=217.9s stop=219.4s speaker_SPEAKER_00
# start=219.5s stop=219.8s speaker_SPEAKER_00
# start=220.5s stop=221.8s speaker_SPEAKER_00
# start=222.3s stop=222.6s speaker_SPEAKER_00
# start=223.5s stop=225.1s speaker_SPEAKER_00
# start=225.9s stop=226.1s speaker_SPEAKER_00
# start=226.1s stop=226.2s speaker_SPEAKER_03
# start=226.2s stop=226.3s speaker_SPEAKER_00
# start=226.3s stop=226.3s speaker_SPEAKER_03
# start=226.3s stop=226.4s speaker_SPEAKER_00
# start=226.4s stop=226.5s speaker_SPEAKER_03
# start=226.5s stop=226.6s speaker_SPEAKER_00
# start=226.6s stop=226.6s speaker_SPEAKER_03
# start=226.9s stop=227.0s speaker_SPEAKER_00
# start=227.0s stop=227.8s speaker_SPEAKER_03
# start=228.1s stop=228.1s speaker_SPEAKER_00
# start=228.1s stop=228.1s speaker_SPEAKER_03
# start=228.1s stop=228.3s speaker_SPEAKER_00
# start=228.3s stop=228.4s speaker_SPEAKER_03
# start=228.4s stop=228.6s speaker_SPEAKER_00
# start=228.6s stop=229.5s speaker_SPEAKER_03
# start=228.6s stop=231.2s speaker_SPEAKER_00
# start=231.2s stop=231.3s speaker_SPEAKER_03
# start=231.5s stop=231.5s speaker_SPEAKER_00
# start=231.5s stop=231.5s speaker_SPEAKER_03
# start=231.5s stop=233.2s speaker_SPEAKER_00
# start=233.4s stop=233.7s speaker_SPEAKER_04
# start=233.8s stop=236.8s speaker_SPEAKER_00
# start=240.1s stop=241.0s speaker_SPEAKER_00
# start=241.0s stop=241.3s speaker_SPEAKER_03
# start=241.3s stop=241.9s speaker_SPEAKER_00
# start=241.3s stop=241.8s speaker_SPEAKER_03
# start=241.9s stop=243.5s speaker_SPEAKER_03
# start=243.8s stop=245.5s speaker_SPEAKER_03
# start=246.1s stop=247.1s speaker_SPEAKER_03
# start=247.9s stop=249.4s speaker_SPEAKER_03
# start=249.6s stop=252.4s speaker_SPEAKER_03
# start=250.2s stop=250.7s speaker_SPEAKER_00
# start=251.6s stop=251.6s speaker_SPEAKER_00
# start=251.6s stop=252.2s speaker_SPEAKER_02
# start=252.2s stop=252.3s speaker_SPEAKER_00
# start=253.2s stop=254.7s speaker_SPEAKER_03
# start=255.8s stop=256.0s speaker_SPEAKER_03
# start=256.0s stop=256.5s speaker_SPEAKER_02
# start=256.8s stop=257.0s speaker_SPEAKER_02
# start=257.0s stop=258.0s speaker_SPEAKER_03
# start=257.2s stop=257.2s speaker_SPEAKER_02
# start=257.2s stop=257.9s speaker_SPEAKER_00
# start=257.9s stop=258.0s speaker_SPEAKER_02
# start=258.0s stop=258.0s speaker_SPEAKER_03
# start=258.2s stop=258.2s speaker_SPEAKER_03
# start=258.2s stop=266.0s speaker_SPEAKER_00
# start=266.0s stop=268.5s speaker_SPEAKER_03
# start=269.6s stop=270.7s speaker_SPEAKER_03
# start=269.7s stop=270.3s speaker_SPEAKER_00
# start=270.3s stop=270.4s speaker_SPEAKER_02
# start=271.2s stop=273.1s speaker_SPEAKER_03
# start=273.4s stop=273.8s speaker_SPEAKER_03
# start=273.9s stop=274.3s speaker_SPEAKER_03
# start=275.4s stop=277.0s speaker_SPEAKER_03
# start=275.9s stop=276.7s speaker_SPEAKER_00
# start=277.0s stop=277.9s speaker_SPEAKER_00
# start=278.2s stop=278.5s speaker_SPEAKER_00
# start=278.5s stop=283.5s speaker_SPEAKER_03
# start=278.6s stop=279.1s speaker_SPEAKER_00
# start=279.6s stop=280.5s speaker_SPEAKER_00
# start=284.3s stop=284.6s speaker_SPEAKER_00
# start=286.3s stop=287.7s speaker_SPEAKER_00
# start=288.9s stop=291.0s speaker_SPEAKER_00
# start=291.6s stop=292.7s speaker_SPEAKER_00
# start=293.3s stop=294.6s speaker_SPEAKER_00
# start=294.9s stop=296.2s speaker_SPEAKER_00
# start=296.3s stop=296.8s speaker_SPEAKER_00
# start=296.4s stop=296.7s speaker_SPEAKER_02
# start=296.8s stop=297.4s speaker_SPEAKER_02
# start=298.5s stop=298.5s speaker_SPEAKER_00
# start=298.5s stop=300.6s speaker_SPEAKER_02
# start=302.8s stop=303.5s speaker_SPEAKER_02
# start=304.4s stop=306.6s speaker_SPEAKER_02
# start=309.0s stop=310.0s speaker_SPEAKER_00
# start=310.1s stop=311.7s speaker_SPEAKER_00
# start=312.1s stop=312.8s speaker_SPEAKER_00
# start=313.5s stop=314.9s speaker_SPEAKER_02
# start=315.8s stop=316.5s speaker_SPEAKER_00
# start=317.5s stop=319.2s speaker_SPEAKER_00
# start=319.5s stop=321.0s speaker_SPEAKER_00
# start=320.4s stop=320.7s speaker_SPEAKER_02
# start=321.0s stop=321.0s speaker_SPEAKER_00
# start=321.1s stop=322.2s speaker_SPEAKER_00
# start=322.6s stop=327.2s speaker_SPEAKER_00
# start=327.9s stop=329.7s speaker_SPEAKER_02
# start=331.1s stop=331.7s speaker_SPEAKER_02
# start=331.8s stop=332.8s speaker_SPEAKER_00
# start=333.6s stop=334.5s speaker_SPEAKER_00
# start=333.7s stop=335.3s speaker_SPEAKER_02
# start=336.2s stop=336.7s speaker_SPEAKER_00
# start=336.8s stop=338.3s speaker_SPEAKER_00
# start=338.9s stop=339.2s speaker_SPEAKER_02
# start=339.4s stop=339.5s speaker_SPEAKER_02
# start=339.5s stop=340.9s speaker_SPEAKER_00
# start=339.5s stop=340.0s speaker_SPEAKER_02
# start=340.0s stop=340.0s speaker_SPEAKER_01
# start=345.1s stop=345.2s speaker_SPEAKER_02
# start=345.2s stop=346.0s speaker_SPEAKER_00
# start=346.0s stop=347.8s speaker_SPEAKER_02
# start=346.4s stop=347.0s speaker_SPEAKER_00
# start=347.0s stop=347.2s speaker_SPEAKER_00
# start=347.8s stop=347.8s speaker_SPEAKER_00
# start=347.8s stop=348.0s speaker_SPEAKER_02
# start=348.1s stop=356.9s speaker_SPEAKER_02
# start=350.0s stop=350.2s speaker_SPEAKER_01
# start=353.1s stop=354.2s speaker_SPEAKER_01
# start=354.2s stop=354.2s speaker_SPEAKER_03
# start=356.4s stop=356.8s speaker_SPEAKER_03
# start=357.5s stop=359.0s speaker_SPEAKER_02
# start=357.5s stop=358.6s speaker_SPEAKER_03
# start=359.0s stop=359.1s speaker_SPEAKER_03
# start=359.1s stop=359.8s speaker_SPEAKER_02
# start=359.8s stop=368.2s speaker_SPEAKER_03
# start=359.8s stop=360.4s speaker_SPEAKER_02
# start=369.4s stop=376.2s speaker_SPEAKER_03
# start=372.5s stop=373.2s speaker_SPEAKER_00
# start=373.2s stop=373.3s speaker_SPEAKER_00
# start=375.1s stop=375.9s speaker_SPEAKER_00
# start=377.0s stop=377.6s speaker_SPEAKER_03
# start=378.2s stop=380.9s speaker_SPEAKER_03
# start=381.4s stop=386.5s speaker_SPEAKER_03
# start=387.1s stop=387.8s speaker_SPEAKER_03
# start=389.7s stop=390.6s speaker_SPEAKER_02
# start=390.9s stop=390.9s speaker_SPEAKER_03
# start=390.9s stop=392.0s speaker_SPEAKER_02
# start=390.9s stop=393.7s speaker_SPEAKER_00
# start=392.8s stop=400.1s speaker_SPEAKER_02
# start=397.5s stop=397.5s speaker_SPEAKER_00
# start=397.5s stop=398.2s speaker_SPEAKER_03
# start=400.1s stop=400.1s speaker_SPEAKER_03
# start=401.6s stop=401.6s speaker_SPEAKER_03
# start=401.6s stop=402.0s speaker_SPEAKER_02
# start=402.0s stop=404.7s speaker_SPEAKER_03
# start=405.9s stop=407.2s speaker_SPEAKER_03
# start=407.5s stop=410.0s speaker_SPEAKER_03
# start=407.7s stop=408.0s speaker_SPEAKER_02
# start=408.0s stop=408.9s speaker_SPEAKER_04
# start=410.7s stop=411.7s speaker_SPEAKER_03
# start=412.5s stop=414.1s speaker_SPEAKER_03
# start=414.7s stop=414.7s speaker_SPEAKER_03
# start=415.4s stop=417.4s speaker_SPEAKER_03
# start=415.5s stop=416.1s speaker_SPEAKER_00
# start=418.3s stop=418.3s speaker_SPEAKER_00
# start=418.3s stop=432.0s speaker_SPEAKER_03
# start=419.1s stop=420.0s speaker_SPEAKER_00
# start=420.0s stop=421.0s speaker_SPEAKER_04
# start=424.0s stop=425.1s speaker_SPEAKER_04
# start=428.3s stop=429.2s speaker_SPEAKER_04
# start=432.3s stop=436.5s speaker_SPEAKER_03
# start=436.8s stop=440.4s speaker_SPEAKER_03
# start=437.4s stop=437.6s speaker_SPEAKER_04
# start=440.8s stop=445.0s speaker_SPEAKER_03
# start=440.8s stop=441.3s speaker_SPEAKER_02
# start=442.0s stop=442.6s speaker_SPEAKER_02
# start=445.4s stop=446.0s speaker_SPEAKER_03
# start=446.9s stop=449.5s speaker_SPEAKER_02
# start=449.6s stop=460.4s speaker_SPEAKER_00
# start=461.8s stop=462.3s speaker_SPEAKER_00
# start=462.8s stop=467.7s speaker_SPEAKER_00
# start=463.0s stop=465.0s speaker_SPEAKER_03
# start=465.8s stop=467.5s speaker_SPEAKER_03
# start=467.9s stop=468.7s speaker_SPEAKER_00
# start=467.9s stop=477.0s speaker_SPEAKER_03
# start=477.4s stop=481.8s speaker_SPEAKER_03
# start=478.5s stop=478.9s speaker_SPEAKER_00
# start=478.9s stop=480.0s speaker_SPEAKER_01
# start=480.0s stop=480.5s speaker_SPEAKER_00
# start=483.4s stop=488.9s speaker_SPEAKER_03
# start=484.3s stop=484.3s speaker_SPEAKER_00
# start=484.3s stop=484.4s speaker_SPEAKER_04
# start=484.4s stop=486.3s speaker_SPEAKER_00
# start=486.3s stop=486.5s speaker_SPEAKER_04
# start=489.5s stop=494.4s speaker_SPEAKER_03
# start=493.1s stop=493.2s speaker_SPEAKER_00
# start=493.2s stop=493.6s speaker_SPEAKER_04
# start=493.6s stop=493.6s speaker_SPEAKER_00
# start=494.7s stop=500.8s speaker_SPEAKER_03
# start=500.9s stop=503.3s speaker_SPEAKER_03
# start=503.5s stop=506.4s speaker_SPEAKER_03
# start=506.8s stop=507.0s speaker_SPEAKER_03
# start=507.2s stop=508.8s speaker_SPEAKER_00
# start=507.4s stop=507.6s speaker_SPEAKER_03
# start=508.3s stop=510.1s speaker_SPEAKER_03
# start=509.1s stop=509.5s speaker_SPEAKER_00
# start=510.4s stop=512.0s speaker_SPEAKER_00
# start=512.0s stop=512.6s speaker_SPEAKER_03
# start=512.6s stop=513.4s speaker_SPEAKER_00
# start=512.6s stop=513.4s speaker_SPEAKER_03
# start=513.4s stop=514.3s speaker_SPEAKER_03
# start=514.3s stop=517.8s speaker_SPEAKER_00
# start=518.2s stop=521.8s speaker_SPEAKER_00
# start=518.4s stop=518.9s speaker_SPEAKER_03
# start=520.8s stop=523.0s speaker_SPEAKER_03
# start=522.3s stop=523.1s speaker_SPEAKER_00
# start=523.1s stop=532.3s speaker_SPEAKER_03
# start=524.4s stop=524.5s speaker_SPEAKER_00
# start=526.0s stop=526.0s speaker_SPEAKER_00
# start=533.6s stop=534.2s speaker_SPEAKER_03
# start=534.4s stop=536.0s speaker_SPEAKER_03
# start=535.1s stop=538.3s speaker_SPEAKER_00
# start=538.3s stop=538.7s speaker_SPEAKER_03
# start=538.7s stop=539.0s speaker_SPEAKER_00
# start=539.0s stop=539.2s speaker_SPEAKER_03
# start=539.5s stop=540.7s speaker_SPEAKER_03
# start=541.1s stop=541.7s speaker_SPEAKER_03
# start=542.1s stop=551.1s speaker_SPEAKER_03
# start=553.6s stop=554.9s speaker_SPEAKER_03
# start=554.1s stop=557.8s speaker_SPEAKER_00
# start=557.2s stop=566.9s speaker_SPEAKER_03
# start=567.4s stop=572.0s speaker_SPEAKER_03
# start=570.1s stop=571.2s speaker_SPEAKER_02
# start=572.0s stop=572.7s speaker_SPEAKER_02
# start=572.7s stop=572.8s speaker_SPEAKER_03
# start=572.8s stop=572.8s speaker_SPEAKER_02
# start=572.8s stop=572.9s speaker_SPEAKER_03
# start=574.5s stop=576.0s speaker_SPEAKER_02
# start=577.1s stop=579.8s speaker_SPEAKER_02
# start=579.1s stop=579.7s speaker_SPEAKER_04
# start=581.1s stop=581.9s speaker_SPEAKER_02
# start=582.2s stop=583.3s speaker_SPEAKER_02
# start=585.2s stop=591.0s speaker_SPEAKER_00
# start=585.5s stop=585.6s speaker_SPEAKER_02
# start=590.1s stop=590.8s speaker_SPEAKER_03
# start=591.0s stop=591.3s speaker_SPEAKER_03
# start=592.2s stop=598.0s speaker_SPEAKER_03
# start=600.9s stop=605.1s speaker_SPEAKER_03
# start=605.7s stop=608.5s speaker_SPEAKER_02
# start=605.8s stop=606.2s speaker_SPEAKER_03
# start=607.5s stop=608.5s speaker_SPEAKER_03
# start=608.5s stop=608.6s speaker_SPEAKER_03
# start=608.6s stop=608.9s speaker_SPEAKER_02
# start=608.9s stop=612.1s speaker_SPEAKER_03
# start=609.6s stop=610.5s speaker_SPEAKER_04
# start=610.5s stop=610.6s speaker_SPEAKER_02
# start=612.9s stop=613.4s speaker_SPEAKER_02
# start=613.4s stop=614.0s speaker_SPEAKER_03
# start=614.0s stop=614.1s speaker_SPEAKER_02
# start=614.1s stop=614.1s speaker_SPEAKER_02
# start=614.1s stop=616.4s speaker_SPEAKER_03
# start=614.2s stop=614.7s speaker_SPEAKER_00
# start=614.7s stop=616.9s speaker_SPEAKER_00
# start=617.4s stop=621.4s speaker_SPEAKER_00
# start=617.6s stop=620.0s speaker_SPEAKER_02
# start=622.3s stop=629.9s speaker_SPEAKER_00
# start=625.4s stop=625.9s speaker_SPEAKER_01
# start=631.2s stop=635.2s speaker_SPEAKER_00
# start=635.3s stop=636.9s speaker_SPEAKER_00
# start=636.9s stop=637.0s speaker_SPEAKER_03
# start=638.1s stop=638.2s speaker_SPEAKER_00
# start=638.2s stop=638.5s speaker_SPEAKER_03
# start=638.8s stop=638.9s speaker_SPEAKER_00
# start=638.9s stop=638.9s speaker_SPEAKER_03
# start=638.9s stop=639.0s speaker_SPEAKER_00
# start=639.0s stop=639.3s speaker_SPEAKER_03
# start=639.3s stop=639.3s speaker_SPEAKER_00
# start=639.3s stop=639.4s speaker_SPEAKER_03
# start=639.4s stop=639.6s speaker_SPEAKER_00
# start=639.6s stop=639.6s speaker_SPEAKER_03
# start=639.6s stop=639.9s speaker_SPEAKER_00
# start=639.9s stop=640.1s speaker_SPEAKER_03
# start=640.6s stop=642.9s speaker_SPEAKER_03
# start=642.9s stop=643.2s speaker_SPEAKER_04
# start=643.2s stop=644.7s speaker_SPEAKER_03
# start=644.7s stop=644.7s speaker_SPEAKER_00
# start=646.5s stop=646.5s speaker_SPEAKER_03
# start=646.5s stop=646.8s speaker_SPEAKER_00
# start=649.7s stop=651.8s speaker_SPEAKER_00
# start=653.1s stop=657.1s speaker_SPEAKER_02
# start=657.7s stop=659.6s speaker_SPEAKER_02
# start=659.6s stop=659.6s speaker_SPEAKER_02
# start=659.6s stop=659.9s speaker_SPEAKER_04
# start=660.7s stop=662.7s speaker_SPEAKER_02
# start=663.8s stop=666.3s speaker_SPEAKER_02
# start=667.9s stop=671.4s speaker_SPEAKER_02
# start=668.0s stop=668.1s speaker_SPEAKER_01
# start=668.1s stop=668.3s speaker_SPEAKER_00
# start=668.3s stop=668.5s speaker_SPEAKER_01
# start=671.9s stop=673.1s speaker_SPEAKER_03
# start=673.1s stop=673.5s speaker_SPEAKER_00
# start=673.1s stop=673.2s speaker_SPEAKER_03
# start=673.2s stop=673.3s speaker_SPEAKER_02
# start=673.3s stop=676.6s speaker_SPEAKER_03
# start=673.5s stop=673.6s speaker_SPEAKER_02
# start=673.6s stop=674.1s speaker_SPEAKER_00
# start=674.1s stop=674.1s speaker_SPEAKER_02
# start=674.1s stop=674.2s speaker_SPEAKER_00
# start=674.2s stop=674.7s speaker_SPEAKER_02
# start=675.3s stop=677.1s speaker_SPEAKER_02
# start=677.6s stop=678.2s speaker_SPEAKER_02
# start=678.3s stop=678.9s speaker_SPEAKER_02
# start=679.5s stop=681.1s speaker_SPEAKER_02
# start=681.5s stop=681.6s speaker_SPEAKER_04
# start=681.6s stop=681.7s speaker_SPEAKER_02
# start=681.7s stop=681.7s speaker_SPEAKER_04
# start=681.8s stop=682.0s speaker_SPEAKER_03
# start=682.0s stop=683.8s speaker_SPEAKER_02
# start=683.9s stop=684.5s speaker_SPEAKER_02
# start=684.7s stop=687.1s speaker_SPEAKER_02
# start=685.0s stop=685.0s speaker_SPEAKER_04
# start=685.0s stop=685.3s speaker_SPEAKER_01
# start=685.3s stop=685.3s speaker_SPEAKER_04
# start=687.9s stop=689.9s speaker_SPEAKER_02
# start=692.3s stop=694.2s speaker_SPEAKER_03
# start=694.3s stop=695.3s speaker_SPEAKER_03
# start=695.8s stop=696.6s speaker_SPEAKER_03
# start=697.4s stop=698.4s speaker_SPEAKER_03
# start=699.2s stop=700.9s speaker_SPEAKER_03
# start=702.0s stop=705.5s speaker_SPEAKER_03
# start=705.7s stop=706.9s speaker_SPEAKER_03
# start=706.0s stop=706.1s speaker_SPEAKER_04
# start=707.2s stop=709.2s speaker_SPEAKER_03
# start=709.8s stop=710.6s speaker_SPEAKER_03
# start=709.9s stop=710.2s speaker_SPEAKER_04
# start=710.7s stop=711.9s speaker_SPEAKER_03
# start=712.9s stop=718.4s speaker_SPEAKER_03
# start=719.1s stop=720.4s speaker_SPEAKER_03
# start=720.8s stop=723.9s speaker_SPEAKER_03
# start=724.9s stop=727.9s speaker_SPEAKER_02
# start=728.0s stop=731.5s speaker_SPEAKER_02
# start=732.0s stop=736.5s speaker_SPEAKER_02
# start=737.1s stop=739.1s speaker_SPEAKER_02
# start=737.9s stop=738.4s speaker_SPEAKER_00
# start=739.4s stop=739.9s speaker_SPEAKER_00
# start=739.5s stop=740.1s speaker_SPEAKER_02
# start=740.7s stop=747.6s speaker_SPEAKER_00
# start=748.4s stop=751.6s speaker_SPEAKER_00
# start=749.4s stop=749.9s speaker_SPEAKER_02
# start=751.9s stop=752.5s speaker_SPEAKER_00
# start=752.6s stop=753.6s speaker_SPEAKER_00
# start=753.1s stop=755.1s speaker_SPEAKER_02
# start=755.3s stop=756.4s speaker_SPEAKER_02
# start=756.4s stop=760.8s speaker_SPEAKER_00
# start=761.3s stop=762.5s speaker_SPEAKER_00
# start=763.2s stop=764.5s speaker_SPEAKER_00
# start=765.2s stop=771.8s speaker_SPEAKER_00
# start=771.2s stop=771.2s speaker_SPEAKER_01
# start=772.4s stop=776.1s speaker_SPEAKER_00
# start=774.3s stop=776.0s speaker_SPEAKER_01
# start=776.4s stop=777.8s speaker_SPEAKER_00
# start=778.2s stop=781.0s speaker_SPEAKER_00
# start=781.7s stop=783.7s speaker_SPEAKER_00
# start=782.5s stop=784.9s speaker_SPEAKER_03
# start=785.5s stop=786.5s speaker_SPEAKER_03
# start=787.0s stop=793.2s speaker_SPEAKER_00
# start=791.8s stop=793.5s speaker_SPEAKER_03
# start=793.8s stop=794.0s speaker_SPEAKER_03
# start=794.0s stop=796.1s speaker_SPEAKER_00
# start=794.1s stop=794.4s speaker_SPEAKER_03
# start=796.2s stop=797.4s speaker_SPEAKER_00
# start=796.2s stop=797.0s speaker_SPEAKER_03
# start=798.3s stop=804.5s speaker_SPEAKER_00
# start=805.3s stop=806.6s speaker_SPEAKER_00
# start=807.6s stop=808.3s speaker_SPEAKER_03
# start=808.7s stop=812.1s speaker_SPEAKER_00
# start=812.6s stop=816.1s speaker_SPEAKER_00
# start=816.9s stop=817.4s speaker_SPEAKER_00
# start=817.8s stop=819.6s speaker_SPEAKER_00
# start=822.5s stop=823.4s speaker_SPEAKER_00
# start=822.9s stop=823.1s speaker_SPEAKER_02
# start=823.7s stop=827.6s speaker_SPEAKER_00
# start=828.6s stop=829.9s speaker_SPEAKER_02
# start=828.6s stop=830.8s speaker_SPEAKER_00
# start=830.8s stop=830.8s speaker_SPEAKER_03
# start=830.8s stop=830.8s speaker_SPEAKER_00
# start=831.0s stop=831.0s speaker_SPEAKER_03
# start=831.0s stop=832.0s speaker_SPEAKER_00
# start=832.0s stop=832.9s speaker_SPEAKER_03
# start=832.9s stop=833.0s speaker_SPEAKER_00
# start=833.0s stop=833.1s speaker_SPEAKER_03
# start=833.4s stop=838.3s speaker_SPEAKER_02
# start=838.5s stop=840.4s speaker_SPEAKER_03
# start=840.7s stop=841.2s speaker_SPEAKER_03
# start=841.8s stop=842.5s speaker_SPEAKER_03
# start=842.6s stop=844.3s speaker_SPEAKER_00
# start=844.6s stop=844.8s speaker_SPEAKER_00
# start=847.5s stop=849.8s speaker_SPEAKER_00
# start=851.5s stop=858.6s speaker_SPEAKER_00
# start=855.1s stop=855.5s speaker_SPEAKER_01
# start=855.5s stop=855.6s speaker_SPEAKER_03
# start=855.6s stop=855.7s speaker_SPEAKER_01
# start=859.2s stop=863.4s speaker_SPEAKER_00
# start=859.7s stop=861.9s speaker_SPEAKER_03
# start=862.1s stop=862.7s speaker_SPEAKER_03
# start=864.1s stop=865.3s speaker_SPEAKER_00
# start=865.6s stop=866.4s speaker_SPEAKER_00
# start=867.7s stop=870.5s speaker_SPEAKER_00
# start=871.4s stop=871.8s speaker_SPEAKER_00
# start=872.1s stop=877.2s speaker_SPEAKER_00
# start=877.7s stop=882.8s speaker_SPEAKER_00
# start=883.5s stop=884.4s speaker_SPEAKER_00
# start=885.1s stop=892.0s speaker_SPEAKER_00
# start=888.6s stop=889.7s speaker_SPEAKER_02
# start=892.0s stop=892.0s speaker_SPEAKER_00
# start=892.0s stop=893.1s speaker_SPEAKER_02
# start=893.1s stop=893.1s speaker_SPEAKER_00
# start=893.1s stop=894.0s speaker_SPEAKER_00
# start=895.1s stop=897.6s speaker_SPEAKER_00
# start=896.4s stop=897.8s speaker_SPEAKER_03
# start=897.9s stop=899.6s speaker_SPEAKER_03
# start=899.9s stop=899.9s speaker_SPEAKER_00
# start=899.9s stop=901.4s speaker_SPEAKER_03
# start=900.4s stop=901.3s speaker_SPEAKER_00
# start=901.3s stop=901.4s speaker_SPEAKER_04
# start=902.0s stop=907.0s speaker_SPEAKER_03
# start=902.0s stop=902.6s speaker_SPEAKER_00
# start=907.3s stop=910.7s speaker_SPEAKER_03
# start=912.0s stop=914.1s speaker_SPEAKER_00
# start=915.2s stop=916.8s speaker_SPEAKER_00
# start=917.3s stop=919.4s speaker_SPEAKER_00
# start=920.0s stop=920.6s speaker_SPEAKER_01
# start=921.3s stop=923.9s speaker_SPEAKER_00
# start=922.2s stop=922.9s speaker_SPEAKER_01
# start=924.6s stop=925.2s speaker_SPEAKER_01
# start=924.6s stop=926.6s speaker_SPEAKER_00
# start=925.7s stop=926.4s speaker_SPEAKER_01
# start=927.6s stop=928.6s speaker_SPEAKER_00
# start=928.8s stop=931.0s speaker_SPEAKER_00
# start=931.4s stop=932.3s speaker_SPEAKER_00
# start=934.1s stop=939.5s speaker_SPEAKER_00
# start=941.5s stop=944.1s speaker_SPEAKER_00
# start=944.5s stop=946.9s speaker_SPEAKER_00
# start=945.3s stop=946.2s speaker_SPEAKER_02
# start=946.9s stop=947.0s speaker_SPEAKER_02
# start=947.0s stop=947.1s speaker_SPEAKER_00
# start=947.1s stop=947.1s speaker_SPEAKER_02
# start=947.1s stop=947.2s speaker_SPEAKER_00
# start=947.7s stop=950.3s speaker_SPEAKER_00
# start=951.0s stop=954.3s speaker_SPEAKER_00
# start=952.4s stop=953.0s speaker_SPEAKER_03
# start=954.5s stop=957.4s speaker_SPEAKER_00
# start=955.1s stop=959.6s speaker_SPEAKER_03
# start=960.1s stop=960.6s speaker_SPEAKER_00
# start=961.4s stop=963.3s speaker_SPEAKER_00
# start=964.7s stop=968.9s speaker_SPEAKER_00
# start=969.7s stop=974.7s speaker_SPEAKER_00
# start=974.7s stop=975.3s speaker_SPEAKER_04
# start=975.2s stop=977.9s speaker_SPEAKER_00
# start=978.4s stop=980.7s speaker_SPEAKER_00
# start=981.0s stop=983.1s speaker_SPEAKER_00
# start=983.9s stop=986.6s speaker_SPEAKER_00
# start=986.7s stop=989.6s speaker_SPEAKER_00
# start=990.6s stop=995.6s speaker_SPEAKER_00
# start=993.6s stop=994.4s speaker_SPEAKER_01
# start=994.7s stop=995.2s speaker_SPEAKER_01
# start=996.5s stop=998.7s speaker_SPEAKER_00
# start=999.6s stop=1002.4s speaker_SPEAKER_00
# start=1003.4s stop=1003.8s speaker_SPEAKER_01
# start=1004.1s stop=1009.1s speaker_SPEAKER_00
# start=1005.2s stop=1005.2s speaker_SPEAKER_02
# start=1005.2s stop=1005.7s speaker_SPEAKER_01
# start=1008.0s stop=1008.0s speaker_SPEAKER_01
# start=1008.0s stop=1008.8s speaker_SPEAKER_02
# start=1008.8s stop=1009.0s speaker_SPEAKER_01
# start=1010.2s stop=1010.2s speaker_SPEAKER_01
# start=1010.2s stop=1010.8s speaker_SPEAKER_00
# start=1011.5s stop=1011.8s speaker_SPEAKER_00
# start=1012.3s stop=1012.9s speaker_SPEAKER_00
# start=1014.5s stop=1015.1s speaker_SPEAKER_00
# start=1015.2s stop=1015.3s speaker_SPEAKER_00
# start=1015.5s stop=1019.5s speaker_SPEAKER_00
# start=1021.3s stop=1026.6s speaker_SPEAKER_00
# start=1027.9s stop=1029.8s speaker_SPEAKER_02
# start=1028.8s stop=1031.8s speaker_SPEAKER_03
# start=1032.6s stop=1036.2s speaker_SPEAKER_03
# start=1036.5s stop=1038.4s speaker_SPEAKER_03
# start=1039.0s stop=1040.4s speaker_SPEAKER_03
# start=1040.6s stop=1041.3s speaker_SPEAKER_03
# start=1041.1s stop=1043.3s speaker_SPEAKER_02
# start=1043.6s stop=1046.9s speaker_SPEAKER_02
# start=1048.0s stop=1051.2s speaker_SPEAKER_00
# start=1049.5s stop=1050.4s speaker_SPEAKER_02
# start=1052.0s stop=1054.8s speaker_SPEAKER_00
# start=1057.7s stop=1059.1s speaker_SPEAKER_00
# start=1059.4s stop=1059.8s speaker_SPEAKER_02
# start=1060.2s stop=1061.7s speaker_SPEAKER_02
# start=1060.2s stop=1061.0s speaker_SPEAKER_00
# start=1064.2s stop=1064.9s speaker_SPEAKER_00
# start=1065.4s stop=1068.0s speaker_SPEAKER_00
# start=1068.5s stop=1070.1s speaker_SPEAKER_00
# start=1068.7s stop=1072.5s speaker_SPEAKER_02
# start=1072.9s stop=1077.7s speaker_SPEAKER_00
# start=1078.1s stop=1078.8s speaker_SPEAKER_00
# start=1079.6s stop=1079.8s speaker_SPEAKER_02
# start=1080.3s stop=1081.3s speaker_SPEAKER_00
# start=1081.6s stop=1083.7s speaker_SPEAKER_02
# start=1082.7s stop=1086.1s speaker_SPEAKER_00
# start=1087.1s stop=1088.4s speaker_SPEAKER_00
# start=1090.1s stop=1091.8s speaker_SPEAKER_03
# start=1092.2s stop=1092.5s speaker_SPEAKER_00
# start=1093.2s stop=1094.7s speaker_SPEAKER_03
# start=1093.5s stop=1096.2s speaker_SPEAKER_00
# start=1096.3s stop=1097.2s speaker_SPEAKER_02
# start=1099.0s stop=1100.4s speaker_SPEAKER_02
# start=1101.0s stop=1102.1s speaker_SPEAKER_00
# start=1101.1s stop=1101.6s speaker_SPEAKER_02
# start=1102.8s stop=1104.1s speaker_SPEAKER_00
# start=1104.9s stop=1107.8s speaker_SPEAKER_00
# start=1108.2s stop=1109.0s speaker_SPEAKER_00
# start=1110.2s stop=1113.0s speaker_SPEAKER_00
# start=1113.3s stop=1115.6s speaker_SPEAKER_00
# start=1117.6s stop=1119.1s speaker_SPEAKER_02
# start=1119.1s stop=1119.2s speaker_SPEAKER_00
# start=1121.1s stop=1121.2s speaker_SPEAKER_00
# start=1124.0s stop=1124.0s speaker_SPEAKER_00
# start=1124.0s stop=1124.0s speaker_SPEAKER_03
# start=1124.0s stop=1126.0s speaker_SPEAKER_00
# start=1126.0s stop=1126.0s speaker_SPEAKER_03
# start=1127.1s stop=1129.8s speaker_SPEAKER_03
# start=1130.7s stop=1131.8s speaker_SPEAKER_00
# start=1131.8s stop=1132.3s speaker_SPEAKER_03
# start=1133.7s stop=1133.7s speaker_SPEAKER_03
# start=1133.7s stop=1134.4s speaker_SPEAKER_02
# start=1135.9s stop=1139.1s speaker_SPEAKER_03
# start=1138.2s stop=1138.9s speaker_SPEAKER_02
# start=1139.7s stop=1140.5s speaker_SPEAKER_03
# start=1140.6s stop=1142.3s speaker_SPEAKER_03
# start=1142.7s stop=1143.8s speaker_SPEAKER_03
# start=1144.1s stop=1146.0s speaker_SPEAKER_03
# start=1146.0s stop=1146.2s speaker_SPEAKER_02
# start=1146.2s stop=1147.0s speaker_SPEAKER_03
# start=1146.3s stop=1147.1s speaker_SPEAKER_02
# start=1150.0s stop=1151.3s speaker_SPEAKER_02
# start=1151.6s stop=1158.0s speaker_SPEAKER_02
# start=1151.8s stop=1152.1s speaker_SPEAKER_00
# start=1158.2s stop=1158.6s speaker_SPEAKER_02
# start=1158.9s stop=1160.1s speaker_SPEAKER_02
# start=1162.4s stop=1162.8s speaker_SPEAKER_03
# start=1162.8s stop=1162.8s speaker_SPEAKER_00
# start=1162.8s stop=1162.8s speaker_SPEAKER_03
# start=1162.8s stop=1163.2s speaker_SPEAKER_00
# start=1163.3s stop=1165.0s speaker_SPEAKER_00
# start=1165.5s stop=1166.4s speaker_SPEAKER_03
# start=1167.3s stop=1171.8s speaker_SPEAKER_03
# start=1167.4s stop=1167.5s speaker_SPEAKER_00
# start=1167.5s stop=1167.8s speaker_SPEAKER_04
# start=1167.8s stop=1167.9s speaker_SPEAKER_00
# start=1167.9s stop=1167.9s speaker_SPEAKER_04
# start=1167.9s stop=1168.9s speaker_SPEAKER_00
# start=1172.1s stop=1172.5s speaker_SPEAKER_03
# start=1173.6s stop=1175.3s speaker_SPEAKER_03
# start=1177.3s stop=1178.0s speaker_SPEAKER_03
# start=1178.2s stop=1178.4s speaker_SPEAKER_02
# start=1178.4s stop=1178.4s speaker_SPEAKER_04
# start=1179.8s stop=1181.3s speaker_SPEAKER_02
# start=1181.7s stop=1181.7s speaker_SPEAKER_03
# start=1181.7s stop=1182.7s speaker_SPEAKER_02
# start=1183.3s stop=1185.2s speaker_SPEAKER_02
# start=1186.4s stop=1188.7s speaker_SPEAKER_00
# start=1190.3s stop=1192.5s speaker_SPEAKER_00
# start=1193.9s stop=1195.5s speaker_SPEAKER_00
# start=1196.1s stop=1197.2s speaker_SPEAKER_00
# start=1197.2s stop=1197.2s speaker_SPEAKER_03
# start=1198.2s stop=1199.5s speaker_SPEAKER_03
# start=1200.1s stop=1201.1s speaker_SPEAKER_03
# start=1201.4s stop=1203.8s speaker_SPEAKER_03
# start=1204.8s stop=1206.7s speaker_SPEAKER_03
# start=1205.3s stop=1208.3s speaker_SPEAKER_00
# start=1208.5s stop=1209.2s speaker_SPEAKER_00
# start=1209.5s stop=1212.8s speaker_SPEAKER_00
# start=1210.8s stop=1211.3s speaker_SPEAKER_02
# start=1213.1s stop=1214.3s speaker_SPEAKER_00
# start=1214.4s stop=1216.5s speaker_SPEAKER_00
# start=1216.5s stop=1216.5s speaker_SPEAKER_03
# start=1217.8s stop=1217.8s speaker_SPEAKER_00
# start=1217.8s stop=1218.5s speaker_SPEAKER_02
# start=1217.8s stop=1218.5s speaker_SPEAKER_03
# start=1218.5s stop=1223.9s speaker_SPEAKER_02
# start=1223.6s stop=1228.9s speaker_SPEAKER_03
# start=1229.6s stop=1230.5s speaker_SPEAKER_03
# start=1230.7s stop=1234.3s speaker_SPEAKER_03
# start=1234.6s stop=1236.6s speaker_SPEAKER_03
# start=1234.8s stop=1234.9s speaker_SPEAKER_04
# start=1237.2s stop=1241.3s speaker_SPEAKER_03
# start=1237.3s stop=1237.3s speaker_SPEAKER_04
# start=1237.3s stop=1237.5s speaker_SPEAKER_01
# start=1240.7s stop=1241.2s speaker_SPEAKER_01
# start=1241.6s stop=1244.3s speaker_SPEAKER_03
# start=1241.6s stop=1243.0s speaker_SPEAKER_01
# start=1243.7s stop=1244.2s speaker_SPEAKER_01
# start=1244.3s stop=1244.6s speaker_SPEAKER_01
# start=1244.6s stop=1244.7s speaker_SPEAKER_03
# start=1244.7s stop=1244.8s speaker_SPEAKER_01
# start=1244.8s stop=1247.1s speaker_SPEAKER_03
# start=1244.8s stop=1245.3s speaker_SPEAKER_01
# start=1246.5s stop=1247.0s speaker_SPEAKER_01
# start=1247.3s stop=1252.9s speaker_SPEAKER_03
# start=1249.1s stop=1249.3s speaker_SPEAKER_01
# start=1251.9s stop=1252.4s speaker_SPEAKER_00
# start=1253.6s stop=1256.6s speaker_SPEAKER_03
# start=1256.7s stop=1259.5s speaker_SPEAKER_03
# start=1260.7s stop=1263.1s speaker_SPEAKER_03
# start=1264.2s stop=1266.7s speaker_SPEAKER_03
# start=1267.0s stop=1272.5s speaker_SPEAKER_03
# start=1267.7s stop=1269.0s speaker_SPEAKER_00
# start=1272.9s stop=1273.7s speaker_SPEAKER_03
# start=1274.0s stop=1274.4s speaker_SPEAKER_03
# start=1275.5s stop=1281.4s speaker_SPEAKER_03
# start=1282.7s stop=1285.3s speaker_SPEAKER_03
# start=1285.3s stop=1285.7s speaker_SPEAKER_00
# start=1286.3s stop=1289.2s speaker_SPEAKER_00
# start=1289.2s stop=1289.2s speaker_SPEAKER_03
# start=1289.2s stop=1289.3s speaker_SPEAKER_00
# start=1289.3s stop=1289.8s speaker_SPEAKER_03
# start=1290.1s stop=1291.6s speaker_SPEAKER_03
# start=1291.8s stop=1293.0s speaker_SPEAKER_03
# start=1291.9s stop=1293.2s speaker_SPEAKER_00
# start=1293.0s stop=1293.0s speaker_SPEAKER_02
# start=1293.5s stop=1293.9s speaker_SPEAKER_00
# start=1293.9s stop=1294.0s speaker_SPEAKER_03
# start=1294.0s stop=1295.7s speaker_SPEAKER_00
# start=1294.1s stop=1295.0s speaker_SPEAKER_03
# start=1295.0s stop=1295.3s speaker_SPEAKER_02
# start=1295.3s stop=1295.4s speaker_SPEAKER_03
# start=1296.2s stop=1299.9s speaker_SPEAKER_00
# start=1300.5s stop=1301.4s speaker_SPEAKER_00
# start=1302.4s stop=1302.7s speaker_SPEAKER_02
# start=1302.7s stop=1304.1s speaker_SPEAKER_00
# start=1304.8s stop=1306.3s speaker_SPEAKER_02
# start=1306.1s stop=1310.1s speaker_SPEAKER_03
# start=1310.6s stop=1311.8s speaker_SPEAKER_03
# start=1312.5s stop=1316.6s speaker_SPEAKER_03
# start=1317.8s stop=1321.8s speaker_SPEAKER_01
# start=1318.4s stop=1319.3s speaker_SPEAKER_03
# start=1321.9s stop=1327.7s speaker_SPEAKER_03
# start=1322.9s stop=1324.0s speaker_SPEAKER_01
# start=1326.8s stop=1327.5s speaker_SPEAKER_01
# start=1327.5s stop=1327.6s speaker_SPEAKER_01
# start=1327.7s stop=1328.0s speaker_SPEAKER_01
# start=1328.0s stop=1331.9s speaker_SPEAKER_03
# start=1328.2s stop=1328.4s speaker_SPEAKER_01
# start=1328.4s stop=1328.8s speaker_SPEAKER_02
# start=1328.8s stop=1328.8s speaker_SPEAKER_01
# start=1329.9s stop=1330.3s speaker_SPEAKER_02
# start=1332.3s stop=1336.3s speaker_SPEAKER_03
# start=1336.1s stop=1336.2s speaker_SPEAKER_00
# start=1336.2s stop=1336.7s speaker_SPEAKER_02
# start=1336.3s stop=1339.6s speaker_SPEAKER_00
# start=1336.7s stop=1336.8s speaker_SPEAKER_03
# start=1339.6s stop=1339.6s speaker_SPEAKER_03
# start=1339.6s stop=1340.6s speaker_SPEAKER_02
# start=1340.6s stop=1340.6s speaker_SPEAKER_01
# start=1341.1s stop=1342.8s speaker_SPEAKER_03
# start=1343.1s stop=1343.1s speaker_SPEAKER_02
# start=1343.1s stop=1343.5s speaker_SPEAKER_01
# start=1343.9s stop=1345.5s speaker_SPEAKER_03
# start=1345.7s stop=1348.0s speaker_SPEAKER_03
# start=1348.6s stop=1349.0s speaker_SPEAKER_03
# start=1349.1s stop=1349.4s speaker_SPEAKER_01
# start=1350.9s stop=1351.8s speaker_SPEAKER_03
# start=1351.1s stop=1351.7s speaker_SPEAKER_01
# start=1351.7s stop=1351.7s speaker_SPEAKER_02
# start=1354.1s stop=1355.3s speaker_SPEAKER_01
# start=1356.4s stop=1356.8s speaker_SPEAKER_01
# start=1357.7s stop=1358.5s speaker_SPEAKER_01
# start=1363.9s stop=1368.1s speaker_SPEAKER_03
# start=1368.6s stop=1371.4s speaker_SPEAKER_03
# start=1372.6s stop=1374.2s speaker_SPEAKER_03
# start=1374.9s stop=1375.7s speaker_SPEAKER_00
# start=1376.2s stop=1379.1s speaker_SPEAKER_00
# start=1380.5s stop=1382.1s speaker_SPEAKER_00
# start=1381.2s stop=1384.1s speaker_SPEAKER_03
# start=1382.1s stop=1382.1s speaker_SPEAKER_02
# start=1384.2s stop=1387.0s speaker_SPEAKER_02
# start=1387.5s stop=1387.6s speaker_SPEAKER_02
# start=1389.3s stop=1390.8s speaker_SPEAKER_02
# start=1392.0s stop=1394.6s speaker_SPEAKER_02
# start=1395.2s stop=1395.5s speaker_SPEAKER_00
# start=1395.7s stop=1396.5s speaker_SPEAKER_02
# start=1396.1s stop=1398.2s speaker_SPEAKER_00
# start=1398.2s stop=1398.2s speaker_SPEAKER_02
# start=1398.6s stop=1399.0s speaker_SPEAKER_00
# start=1398.7s stop=1399.4s speaker_SPEAKER_02
# start=1400.9s stop=1402.0s speaker_SPEAKER_02
# start=1402.7s stop=1404.7s speaker_SPEAKER_02
# start=1403.9s stop=1407.2s speaker_SPEAKER_03
# start=1405.5s stop=1406.4s speaker_SPEAKER_02
# start=1407.7s stop=1410.3s speaker_SPEAKER_03
# start=1410.6s stop=1412.2s speaker_SPEAKER_03
# start=1412.2s stop=1412.6s speaker_SPEAKER_04
# start=1412.6s stop=1414.6s speaker_SPEAKER_03
# start=1412.7s stop=1414.4s speaker_SPEAKER_04
# start=1415.0s stop=1422.6s speaker_SPEAKER_03
# start=1423.6s stop=1424.6s speaker_SPEAKER_03
# start=1426.1s stop=1429.1s speaker_SPEAKER_03
# start=1431.2s stop=1436.1s speaker_SPEAKER_03
# start=1438.4s stop=1445.3s speaker_SPEAKER_03
# start=1445.5s stop=1447.0s speaker_SPEAKER_03
# start=1447.6s stop=1451.1s speaker_SPEAKER_03
# start=1451.5s stop=1454.1s speaker_SPEAKER_03
# start=1454.4s stop=1455.8s speaker_SPEAKER_03
# start=1456.3s stop=1457.0s speaker_SPEAKER_03
# start=1457.0s stop=1457.0s speaker_SPEAKER_00
# start=1458.8s stop=1461.1s speaker_SPEAKER_02
# start=1460.0s stop=1460.0s speaker_SPEAKER_03
# start=1460.0s stop=1460.2s speaker_SPEAKER_00
# start=1460.2s stop=1460.2s speaker_SPEAKER_03
# start=1460.2s stop=1460.3s speaker_SPEAKER_00
# start=1460.3s stop=1460.3s speaker_SPEAKER_03
# start=1460.3s stop=1460.5s speaker_SPEAKER_00
# start=1461.9s stop=1465.2s speaker_SPEAKER_00
# start=1465.4s stop=1469.7s speaker_SPEAKER_00
# start=1467.6s stop=1468.4s speaker_SPEAKER_03
# start=1468.8s stop=1470.5s speaker_SPEAKER_03
# start=1470.9s stop=1473.8s speaker_SPEAKER_00
# start=1475.6s stop=1475.7s speaker_SPEAKER_03
# start=1475.7s stop=1476.2s speaker_SPEAKER_00
# start=1475.8s stop=1476.1s speaker_SPEAKER_04
# start=1476.1s stop=1476.1s speaker_SPEAKER_03
# start=1476.2s stop=1476.2s speaker_SPEAKER_03
# start=1476.9s stop=1480.0s speaker_SPEAKER_00
# start=1481.8s stop=1482.8s speaker_SPEAKER_00
# start=1483.1s stop=1487.6s speaker_SPEAKER_00
# start=1486.7s stop=1486.7s speaker_SPEAKER_02
# start=1486.7s stop=1487.7s speaker_SPEAKER_04
# start=1487.7s stop=1487.8s speaker_SPEAKER_00
# start=1488.1s stop=1491.6s speaker_SPEAKER_00
# start=1492.3s stop=1493.8s speaker_SPEAKER_00
# start=1493.1s stop=1493.7s speaker_SPEAKER_02
# start=1493.8s stop=1494.0s speaker_SPEAKER_02
# start=1494.0s stop=1494.0s speaker_SPEAKER_00
# start=1494.7s stop=1495.4s speaker_SPEAKER_00
# start=1496.3s stop=1500.8s speaker_SPEAKER_00
# start=1499.1s stop=1499.8s speaker_SPEAKER_03
# start=1501.1s stop=1501.9s speaker_SPEAKER_03
# start=1501.3s stop=1501.7s speaker_SPEAKER_00
# start=1503.2s stop=1503.5s speaker_SPEAKER_00
# start=1505.9s stop=1506.9s speaker_SPEAKER_00
# start=1507.0s stop=1507.1s speaker_SPEAKER_00
# start=1507.1s stop=1507.8s speaker_SPEAKER_00
# start=1508.7s stop=1509.8s speaker_SPEAKER_00
# start=1510.0s stop=1510.0s speaker_SPEAKER_00
# start=1510.1s stop=1511.0s speaker_SPEAKER_00
# start=1510.4s stop=1510.8s speaker_SPEAKER_01
# start=1511.6s stop=1513.0s speaker_SPEAKER_00
# start=1512.6s stop=1513.3s speaker_SPEAKER_02
# start=1513.7s stop=1513.9s speaker_SPEAKER_00
# start=1514.4s stop=1516.7s speaker_SPEAKER_02
# start=1518.8s stop=1521.9s speaker_SPEAKER_00
# start=1522.0s stop=1522.0s speaker_SPEAKER_00
# start=1522.0s stop=1523.3s speaker_SPEAKER_02
# start=1522.5s stop=1525.7s speaker_SPEAKER_00
# start=1525.8s stop=1530.0s speaker_SPEAKER_00
# start=1526.0s stop=1527.4s speaker_SPEAKER_02
# start=1527.4s stop=1527.5s speaker_SPEAKER_01
# start=1528.7s stop=1529.6s speaker_SPEAKER_03
# start=1530.0s stop=1530.4s speaker_SPEAKER_03
# start=1530.4s stop=1530.7s speaker_SPEAKER_00
# start=1530.7s stop=1530.7s speaker_SPEAKER_03
# start=1532.1s stop=1541.2s speaker_SPEAKER_00
# start=1540.6s stop=1542.0s speaker_SPEAKER_01
# start=1541.5s stop=1543.8s speaker_SPEAKER_00
# start=1542.0s stop=1542.4s speaker_SPEAKER_02
# start=1542.4s stop=1542.9s speaker_SPEAKER_01
# start=1542.9s stop=1543.9s speaker_SPEAKER_02
# start=1543.8s stop=1545.0s speaker_SPEAKER_01
# start=1544.3s stop=1546.4s speaker_SPEAKER_02
# start=1545.0s stop=1545.7s speaker_SPEAKER_03
# start=1547.1s stop=1548.6s speaker_SPEAKER_02
# start=1550.1s stop=1550.1s speaker_SPEAKER_03
# start=1550.1s stop=1551.6s speaker_SPEAKER_00
# start=1551.6s stop=1551.6s speaker_SPEAKER_03
# start=1551.8s stop=1552.3s speaker_SPEAKER_03
# start=1553.4s stop=1557.5s speaker_SPEAKER_00
# start=1559.4s stop=1563.0s speaker_SPEAKER_00
# start=1560.3s stop=1560.5s speaker_SPEAKER_04
# start=1563.6s stop=1571.0s speaker_SPEAKER_00
# start=1563.8s stop=1564.0s speaker_SPEAKER_04
# start=1564.0s stop=1564.0s speaker_SPEAKER_02
# start=1564.0s stop=1564.2s speaker_SPEAKER_04
# start=1571.0s stop=1571.6s speaker_SPEAKER_03
# start=1572.6s stop=1573.0s speaker_SPEAKER_00
# start=1573.6s stop=1576.4s speaker_SPEAKER_03
# start=1577.5s stop=1577.9s speaker_SPEAKER_03
# start=1578.2s stop=1579.1s speaker_SPEAKER_03
# start=1580.6s stop=1580.7s speaker_SPEAKER_03
# start=1580.7s stop=1580.8s speaker_SPEAKER_02
# start=1580.8s stop=1582.7s speaker_SPEAKER_03
# start=1582.8s stop=1582.9s speaker_SPEAKER_03
# start=1582.9s stop=1583.1s speaker_SPEAKER_04
# start=1583.7s stop=1584.7s speaker_SPEAKER_03
# start=1584.7s stop=1584.7s speaker_SPEAKER_00
# start=1588.7s stop=1589.2s speaker_SPEAKER_00
# start=1589.6s stop=1591.7s speaker_SPEAKER_00
# start=1592.0s stop=1594.6s speaker_SPEAKER_00
# start=1594.6s stop=1594.6s speaker_SPEAKER_03
# start=1595.3s stop=1595.6s speaker_SPEAKER_04
# start=1596.0s stop=1596.2s speaker_SPEAKER_03
# start=1596.3s stop=1596.3s speaker_SPEAKER_03
# start=1596.4s stop=1601.9s speaker_SPEAKER_03
# start=1601.9s stop=1605.8s speaker_SPEAKER_00
# start=1604.2s stop=1619.1s speaker_SPEAKER_03
# start=1610.7s stop=1610.9s speaker_SPEAKER_00
# start=1611.3s stop=1612.0s speaker_SPEAKER_00
# start=1616.1s stop=1616.6s speaker_SPEAKER_00
# start=1617.8s stop=1623.1s speaker_SPEAKER_00
# start=1623.1s stop=1623.2s speaker_SPEAKER_04
# start=1623.2s stop=1623.4s speaker_SPEAKER_00
# start=1623.4s stop=1623.5s speaker_SPEAKER_04
# start=1623.5s stop=1625.1s speaker_SPEAKER_00
# start=1623.5s stop=1623.5s speaker_SPEAKER_04
# start=1623.5s stop=1623.8s speaker_SPEAKER_03
# start=1625.1s stop=1625.2s speaker_SPEAKER_03
# start=1625.2s stop=1625.2s speaker_SPEAKER_00
# start=1625.2s stop=1626.6s speaker_SPEAKER_03
# start=1627.0s stop=1629.2s speaker_SPEAKER_03
# start=1629.6s stop=1633.8s speaker_SPEAKER_03
# start=1633.9s stop=1633.9s speaker_SPEAKER_03
# start=1633.9s stop=1634.7s speaker_SPEAKER_00
# start=1634.7s stop=1634.8s speaker_SPEAKER_03
# start=1635.2s stop=1636.8s speaker_SPEAKER_00
# start=1637.0s stop=1643.0s speaker_SPEAKER_00
# start=1643.0s stop=1644.1s speaker_SPEAKER_04
# start=1643.9s stop=1649.9s speaker_SPEAKER_00
# start=1644.2s stop=1644.2s speaker_SPEAKER_04
# start=1645.2s stop=1646.0s speaker_SPEAKER_04
# start=1647.2s stop=1648.1s speaker_SPEAKER_04
# start=1651.7s stop=1652.0s speaker_SPEAKER_01
# start=1654.5s stop=1654.6s speaker_SPEAKER_00
# start=1654.6s stop=1654.7s speaker_SPEAKER_02
# start=1654.7s stop=1655.0s speaker_SPEAKER_00
# start=1655.0s stop=1655.7s speaker_SPEAKER_02
# start=1656.4s stop=1657.6s speaker_SPEAKER_02
# start=1658.8s stop=1658.8s speaker_SPEAKER_02
# start=1658.8s stop=1659.5s speaker_SPEAKER_00
# start=1659.6s stop=1660.7s speaker_SPEAKER_00
# start=1661.3s stop=1661.9s speaker_SPEAKER_02
# start=1661.5s stop=1665.8s speaker_SPEAKER_00
# start=1665.4s stop=1665.7s speaker_SPEAKER_02
# start=1665.7s stop=1665.8s speaker_SPEAKER_01
# start=1665.8s stop=1667.1s speaker_SPEAKER_01
# start=1667.4s stop=1670.6s speaker_SPEAKER_00
# start=1667.7s stop=1668.5s speaker_SPEAKER_01
# start=1670.0s stop=1671.4s speaker_SPEAKER_01
# start=1671.4s stop=1671.6s speaker_SPEAKER_00
# start=1671.6s stop=1671.7s speaker_SPEAKER_01
# start=1671.7s stop=1671.8s speaker_SPEAKER_00
# start=1671.8s stop=1671.9s speaker_SPEAKER_01
# start=1671.9s stop=1672.3s speaker_SPEAKER_00
# start=1673.6s stop=1676.7s speaker_SPEAKER_00
# start=1677.9s stop=1678.0s speaker_SPEAKER_00
# start=1678.0s stop=1678.0s speaker_SPEAKER_01
# start=1678.0s stop=1679.8s speaker_SPEAKER_04
# start=1679.8s stop=1680.0s speaker_SPEAKER_00
# start=1680.0s stop=1680.5s speaker_SPEAKER_04
# start=1681.1s stop=1682.5s speaker_SPEAKER_04
# start=1683.0s stop=1685.5s speaker_SPEAKER_04
# start=1683.7s stop=1683.9s speaker_SPEAKER_00
# start=1685.6s stop=1686.7s speaker_SPEAKER_04
# start=1686.7s stop=1688.1s speaker_SPEAKER_02
# start=1687.3s stop=1687.5s speaker_SPEAKER_04
# start=1688.1s stop=1688.2s speaker_SPEAKER_03
# start=1688.8s stop=1689.8s speaker_SPEAKER_03
# start=1689.8s stop=1689.8s speaker_SPEAKER_02
# start=1690.0s stop=1693.4s speaker_SPEAKER_02
# start=1690.4s stop=1691.1s speaker_SPEAKER_03
# start=1693.5s stop=1695.1s speaker_SPEAKER_03
# start=1698.4s stop=1703.2s speaker_SPEAKER_03
# start=1701.2s stop=1701.3s speaker_SPEAKER_00
# start=1701.3s stop=1701.5s speaker_SPEAKER_04
# start=1701.5s stop=1701.6s speaker_SPEAKER_00
# start=1702.9s stop=1704.5s speaker_SPEAKER_01
# start=1703.2s stop=1703.6s speaker_SPEAKER_04
# start=1703.6s stop=1704.0s speaker_SPEAKER_03
# start=1706.8s stop=1707.0s speaker_SPEAKER_03
# start=1707.0s stop=1710.3s speaker_SPEAKER_02
# start=1714.3s stop=1714.8s speaker_SPEAKER_03
# start=1715.0s stop=1718.0s speaker_SPEAKER_03
# start=1718.0s stop=1720.9s speaker_SPEAKER_00
# start=1722.1s stop=1723.7s speaker_SPEAKER_00
# start=1728.1s stop=1730.2s speaker_SPEAKER_02
# start=1730.1s stop=1732.6s speaker_SPEAKER_00
# start=1733.4s stop=1733.7s speaker_SPEAKER_00
# start=1733.8s stop=1735.3s speaker_SPEAKER_00
# start=1737.2s stop=1738.3s speaker_SPEAKER_00
# start=1738.9s stop=1740.5s speaker_SPEAKER_00
# start=1740.7s stop=1741.6s speaker_SPEAKER_00
# start=1742.4s stop=1744.4s speaker_SPEAKER_00
# start=1744.5s stop=1745.5s speaker_SPEAKER_00
# start=1746.7s stop=1747.8s speaker_SPEAKER_00
# start=1750.1s stop=1751.7s speaker_SPEAKER_00
# start=1751.8s stop=1752.0s speaker_SPEAKER_00
# start=1752.0s stop=1752.0s speaker_SPEAKER_02
# start=1752.0s stop=1752.1s speaker_SPEAKER_00
# start=1752.1s stop=1752.1s speaker_SPEAKER_00
# start=1752.1s stop=1752.2s speaker_SPEAKER_02
# start=1752.2s stop=1754.0s speaker_SPEAKER_01
# start=1754.0s stop=1754.0s speaker_SPEAKER_02
# start=1754.0s stop=1754.0s speaker_SPEAKER_00
# start=1756.6s stop=1756.7s speaker_SPEAKER_03
# start=1756.7s stop=1756.8s speaker_SPEAKER_00
# start=1756.8s stop=1756.9s speaker_SPEAKER_03
# start=1757.0s stop=1757.0s speaker_SPEAKER_03
# start=1757.0s stop=1757.6s speaker_SPEAKER_00
# start=1757.6s stop=1757.7s speaker_SPEAKER_03
# start=1757.7s stop=1757.8s speaker_SPEAKER_00
# start=1763.9s stop=1765.4s speaker_SPEAKER_00
# start=1765.9s stop=1766.6s speaker_SPEAKER_00
# start=1766.6s stop=1768.6s speaker_SPEAKER_02
# start=1766.8s stop=1768.3s speaker_SPEAKER_00
# start=1768.6s stop=1770.6s speaker_SPEAKER_00
# start=1771.9s stop=1773.0s speaker_SPEAKER_02
# start=1773.0s stop=1773.3s speaker_SPEAKER_00
# start=1774.5s stop=1776.4s speaker_SPEAKER_00
# start=1779.7s stop=1781.0s speaker_SPEAKER_00
# start=1781.3s stop=1783.2s speaker_SPEAKER_00
# start=1786.0s stop=1787.9s speaker_SPEAKER_02
# start=1788.1s stop=1792.5s speaker_SPEAKER_00
# start=1792.8s stop=1795.2s speaker_SPEAKER_02
# start=1793.4s stop=1793.6s speaker_SPEAKER_00
# start=1794.3s stop=1794.7s speaker_SPEAKER_00
# start=1794.7s stop=1794.7s speaker_SPEAKER_04
# start=1794.7s stop=1794.9s speaker_SPEAKER_00
# start=1795.7s stop=1798.6s speaker_SPEAKER_00
# start=1799.7s stop=1803.1s speaker_SPEAKER_00
# start=1803.5s stop=1806.2s speaker_SPEAKER_00
# start=1805.8s stop=1806.3s speaker_SPEAKER_03
# start=1806.7s stop=1813.7s speaker_SPEAKER_03
# start=1814.2s stop=1815.1s speaker_SPEAKER_03
# start=1814.2s stop=1814.8s speaker_SPEAKER_00
# start=1815.5s stop=1817.5s speaker_SPEAKER_03
# start=1818.0s stop=1820.8s speaker_SPEAKER_03
# start=1819.1s stop=1822.6s speaker_SPEAKER_00
# start=1822.6s stop=1822.9s speaker_SPEAKER_03
# start=1822.9s stop=1823.0s speaker_SPEAKER_00
# start=1823.0s stop=1824.3s speaker_SPEAKER_03
# start=1825.1s stop=1827.8s speaker_SPEAKER_03
# start=1827.6s stop=1827.8s speaker_SPEAKER_00
# start=1827.8s stop=1827.9s speaker_SPEAKER_00
# start=1828.5s stop=1829.1s speaker_SPEAKER_03
# start=1829.2s stop=1829.2s speaker_SPEAKER_03
# start=1829.2s stop=1829.5s speaker_SPEAKER_00
# start=1829.5s stop=1829.5s speaker_SPEAKER_03
# start=1830.4s stop=1830.4s speaker_SPEAKER_03
# start=1830.4s stop=1833.4s speaker_SPEAKER_00
# start=1832.0s stop=1832.2s speaker_SPEAKER_03
# start=1832.2s stop=1832.3s speaker_SPEAKER_02
# ...
# start=2113.9s stop=2123.0s speaker_SPEAKER_00
# start=2114.8s stop=2120.0s speaker_SPEAKER_02
# start=2123.2s stop=2126.7s speaker_SPEAKER_00
# start=2127.2s stop=2130.2s speaker_SPEAKER_00
# start=2130.6s stop=2133.1s speaker_SPEAKER_00
# start=2133.3s stop=2135.1s speaker_SPEAKER_00
# start=2135.7s stop=2144.2s speaker_SPEAKER_00
# start=2142.6s stop=2147.5s speaker_SPEAKER_02
# start=2144.2s stop=2144.2s speaker_SPEAKER_03
# start=2145.9s stop=2147.9s speaker_SPEAKER_03
# start=2147.9s stop=2148.0s speaker_SPEAKER_02
# start=2148.0s stop=2148.0s speaker_SPEAKER_03
# start=2148.0s stop=2157.3s speaker_SPEAKER_02
# start=2150.3s stop=2151.0s speaker_SPEAKER_03
# start=2151.0s stop=2151.4s speaker_SPEAKER_00
# start=2155.6s stop=2159.7s speaker_SPEAKER_00
# start=2160.1s stop=2161.0s speaker_SPEAKER_00
# start=2160.7s stop=2160.8s speaker_SPEAKER_03
# start=2160.8s stop=2161.0s speaker_SPEAKER_02
# start=2161.8s stop=2161.8s speaker_SPEAKER_00
# start=2161.8s stop=2162.0s speaker_SPEAKER_03
# start=2162.0s stop=2164.3s speaker_SPEAKER_00
# start=2162.7s stop=2164.6s speaker_SPEAKER_03
# start=2164.8s stop=2173.0s speaker_SPEAKER_03
# start=2165.5s stop=2166.7s speaker_SPEAKER_00
# start=2173.4s stop=2177.2s speaker_SPEAKER_03
# start=2177.5s stop=2182.8s speaker_SPEAKER_03
# start=2183.2s stop=2184.0s speaker_SPEAKER_03
# start=2184.2s stop=2196.0s speaker_SPEAKER_03
# start=2185.2s stop=2185.7s speaker_SPEAKER_00
# start=2188.1s stop=2188.4s speaker_SPEAKER_00
# start=2196.2s stop=2198.8s speaker_SPEAKER_03
# start=2198.8s stop=2198.9s speaker_SPEAKER_04
# start=2198.9s stop=2200.9s speaker_SPEAKER_03
# start=2201.1s stop=2203.5s speaker_SPEAKER_03
# start=2203.6s stop=2204.0s speaker_SPEAKER_03
# start=2205.0s stop=2208.6s speaker_SPEAKER_03
# start=2208.7s stop=2211.1s speaker_SPEAKER_03
# start=2211.1s stop=2211.6s speaker_SPEAKER_04
# start=2211.6s stop=2212.1s speaker_SPEAKER_03
# start=2212.3s stop=2214.5s speaker_SPEAKER_03
# start=2215.9s stop=2219.9s speaker_SPEAKER_03
# start=2216.3s stop=2216.3s speaker_SPEAKER_04
# start=2216.3s stop=2217.9s speaker_SPEAKER_00
# start=2221.2s stop=2228.6s speaker_SPEAKER_03
# start=2228.0s stop=2228.6s speaker_SPEAKER_00
# start=2228.6s stop=2229.6s speaker_SPEAKER_00
# start=2230.7s stop=2234.0s speaker_SPEAKER_00
# start=2235.5s stop=2238.2s speaker_SPEAKER_02
# start=2236.0s stop=2236.8s speaker_SPEAKER_00
# start=2236.8s stop=2236.9s speaker_SPEAKER_03
# start=2238.6s stop=2240.1s speaker_SPEAKER_02
# start=2242.0s stop=2242.4s speaker_SPEAKER_02
# start=2242.9s stop=2245.4s speaker_SPEAKER_02
# start=2246.0s stop=2248.3s speaker_SPEAKER_02
# start=2248.9s stop=2249.1s speaker_SPEAKER_02
# start=2249.1s stop=2249.1s speaker_SPEAKER_00
# start=2249.1s stop=2249.2s speaker_SPEAKER_02
# start=2249.2s stop=2250.2s speaker_SPEAKER_00
# start=2250.2s stop=2251.0s speaker_SPEAKER_02
# start=2251.0s stop=2251.6s speaker_SPEAKER_00
# start=2251.6s stop=2253.2s speaker_SPEAKER_02
# start=2252.3s stop=2252.3s speaker_SPEAKER_00
# start=2252.3s stop=2252.4s speaker_SPEAKER_04
# start=2252.4s stop=2252.5s speaker_SPEAKER_00
# start=2252.5s stop=2252.5s speaker_SPEAKER_04
# start=2252.5s stop=2252.7s speaker_SPEAKER_00
# start=2252.7s stop=2252.8s speaker_SPEAKER_01
# start=2254.0s stop=2261.3s speaker_SPEAKER_02
# start=2262.4s stop=2269.5s speaker_SPEAKER_02
# start=2267.2s stop=2268.5s speaker_SPEAKER_03
# start=2270.6s stop=2270.9s speaker_SPEAKER_02
# start=2272.6s stop=2279.4s speaker_SPEAKER_02
# start=2279.8s stop=2281.4s speaker_SPEAKER_02
# start=2279.9s stop=2280.5s speaker_SPEAKER_00
# start=2281.6s stop=2285.7s speaker_SPEAKER_02
# start=2286.1s stop=2286.9s speaker_SPEAKER_02
# start=2287.9s stop=2289.6s speaker_SPEAKER_02
# start=2290.4s stop=2292.5s speaker_SPEAKER_00
# start=2293.9s stop=2298.0s speaker_SPEAKER_02
# start=2295.0s stop=2295.2s speaker_SPEAKER_00
# start=2295.2s stop=2296.0s speaker_SPEAKER_03
# start=2296.9s stop=2299.4s speaker_SPEAKER_00
# start=2298.0s stop=2298.6s speaker_SPEAKER_03
# start=2298.6s stop=2298.6s speaker_SPEAKER_02
# start=2298.6s stop=2298.6s speaker_SPEAKER_03
# start=2299.6s stop=2301.5s speaker_SPEAKER_00
# start=2300.7s stop=2301.5s speaker_SPEAKER_03
# start=2301.5s stop=2303.0s speaker_SPEAKER_03
# start=2303.7s stop=2303.7s speaker_SPEAKER_00
# start=2303.7s stop=2303.7s speaker_SPEAKER_03
# start=2303.7s stop=2307.3s speaker_SPEAKER_00
# start=2304.1s stop=2304.9s speaker_SPEAKER_03
# start=2307.7s stop=2308.8s speaker_SPEAKER_03
# start=2309.5s stop=2316.2s speaker_SPEAKER_03
# start=2316.6s stop=2320.4s speaker_SPEAKER_03
# start=2316.7s stop=2316.7s speaker_SPEAKER_02
# start=2316.7s stop=2316.7s speaker_SPEAKER_04
# start=2316.7s stop=2317.0s speaker_SPEAKER_02
# start=2317.0s stop=2317.0s speaker_SPEAKER_04
# start=2317.0s stop=2318.0s speaker_SPEAKER_02
# start=2318.0s stop=2320.4s speaker_SPEAKER_04
# start=2320.4s stop=2320.6s speaker_SPEAKER_04
# start=2320.6s stop=2320.6s speaker_SPEAKER_03
# start=2320.6s stop=2320.8s speaker_SPEAKER_04
# start=2320.8s stop=2321.7s speaker_SPEAKER_03
# start=2321.0s stop=2321.1s speaker_SPEAKER_04
# start=2321.1s stop=2323.3s speaker_SPEAKER_02
# start=2323.8s stop=2326.4s speaker_SPEAKER_02
# start=2326.5s stop=2331.5s speaker_SPEAKER_03
# start=2330.8s stop=2337.1s speaker_SPEAKER_00
# start=2338.1s stop=2339.1s speaker_SPEAKER_00
# start=2339.5s stop=2340.8s speaker_SPEAKER_00
# start=2341.2s stop=2359.7s speaker_SPEAKER_00
# start=2342.9s stop=2343.0s speaker_SPEAKER_01
# start=2347.1s stop=2347.7s speaker_SPEAKER_01
# start=2355.2s stop=2356.2s speaker_SPEAKER_02
# start=2356.2s stop=2356.3s speaker_SPEAKER_01
# start=2360.0s stop=2360.1s speaker_SPEAKER_00
# start=2360.1s stop=2360.6s speaker_SPEAKER_03
# start=2360.6s stop=2360.6s speaker_SPEAKER_00
# start=2361.4s stop=2361.5s speaker_SPEAKER_03
# start=2361.5s stop=2361.6s speaker_SPEAKER_00
# start=2361.6s stop=2361.7s speaker_SPEAKER_03
# start=2361.7s stop=2362.1s speaker_SPEAKER_00
# start=2361.8s stop=2366.3s speaker_SPEAKER_03
# start=2362.8s stop=2363.5s speaker_SPEAKER_00
# start=2364.5s stop=2365.1s speaker_SPEAKER_00
# start=2367.0s stop=2381.1s speaker_SPEAKER_03
# start=2374.6s stop=2374.6s speaker_SPEAKER_00
# start=2374.6s stop=2374.6s speaker_SPEAKER_01
# start=2374.6s stop=2374.8s speaker_SPEAKER_00
# start=2374.8s stop=2375.4s speaker_SPEAKER_02
# start=2375.4s stop=2375.5s speaker_SPEAKER_00
# start=2377.0s stop=2378.2s speaker_SPEAKER_00
# start=2381.5s stop=2387.4s speaker_SPEAKER_03
# start=2385.9s stop=2386.7s speaker_SPEAKER_00
# start=2386.7s stop=2390.2s speaker_SPEAKER_00
# start=2388.9s stop=2389.6s speaker_SPEAKER_03
# start=2390.2s stop=2393.6s speaker_SPEAKER_03
# start=2390.2s stop=2392.9s speaker_SPEAKER_00
# start=2393.8s stop=2396.1s speaker_SPEAKER_03
# start=2396.9s stop=2401.1s speaker_SPEAKER_03
# start=2397.2s stop=2398.0s speaker_SPEAKER_00
# start=2398.0s stop=2398.0s speaker_SPEAKER_04
# start=2398.0s stop=2399.5s speaker_SPEAKER_02
# start=2402.3s stop=2402.6s speaker_SPEAKER_03
# start=2403.2s stop=2405.8s speaker_SPEAKER_03
# start=2406.1s stop=2406.5s speaker_SPEAKER_03
# start=2406.7s stop=2408.2s speaker_SPEAKER_00
# start=2408.8s stop=2412.1s speaker_SPEAKER_00
# start=2410.1s stop=2410.2s speaker_SPEAKER_02
# start=2410.2s stop=2411.0s speaker_SPEAKER_03
# start=2411.0s stop=2413.0s speaker_SPEAKER_02
# start=2412.1s stop=2412.1s speaker_SPEAKER_03
# start=2412.1s stop=2412.1s speaker_SPEAKER_00
# start=2413.2s stop=2413.2s speaker_SPEAKER_00
# start=2413.2s stop=2419.7s speaker_SPEAKER_02
# start=2414.7s stop=2415.2s speaker_SPEAKER_00
# start=2418.6s stop=2419.0s speaker_SPEAKER_03
# start=2419.0s stop=2419.7s speaker_SPEAKER_04
# start=2420.2s stop=2426.0s speaker_SPEAKER_02
# start=2424.6s stop=2425.8s speaker_SPEAKER_00
# start=2426.5s stop=2427.6s speaker_SPEAKER_02
# start=2428.8s stop=2430.3s speaker_SPEAKER_02
# start=2429.4s stop=2433.0s speaker_SPEAKER_00
# start=2433.3s stop=2435.3s speaker_SPEAKER_00
# start=2435.4s stop=2439.6s speaker_SPEAKER_02
# start=2436.4s stop=2437.2s speaker_SPEAKER_00
# start=2440.1s stop=2441.5s speaker_SPEAKER_02
# start=2441.8s stop=2442.4s speaker_SPEAKER_02
# start=2442.7s stop=2443.6s speaker_SPEAKER_02
# start=2444.5s stop=2445.7s speaker_SPEAKER_02
# start=2445.9s stop=2448.5s speaker_SPEAKER_02
# start=2446.9s stop=2447.0s speaker_SPEAKER_00
# start=2447.0s stop=2447.3s speaker_SPEAKER_00
# start=2447.3s stop=2447.8s speaker_SPEAKER_04
# start=2447.8s stop=2447.8s speaker_SPEAKER_00
# start=2447.8s stop=2447.8s speaker_SPEAKER_04
# start=2448.9s stop=2451.2s speaker_SPEAKER_02
# start=2448.9s stop=2449.4s speaker_SPEAKER_00
# start=2452.3s stop=2454.5s speaker_SPEAKER_02
# start=2452.3s stop=2455.9s speaker_SPEAKER_00
# start=2456.3s stop=2464.3s speaker_SPEAKER_00
# start=2464.9s stop=2467.0s speaker_SPEAKER_00
# start=2466.2s stop=2468.7s speaker_SPEAKER_03
# start=2469.7s stop=2471.6s speaker_SPEAKER_00
# start=2469.8s stop=2471.3s speaker_SPEAKER_03
# start=2471.6s stop=2472.3s speaker_SPEAKER_03
# start=2472.8s stop=2473.0s speaker_SPEAKER_03
# start=2473.0s stop=2474.0s speaker_SPEAKER_02
# start=2475.4s stop=2476.4s speaker_SPEAKER_02
# start=2476.2s stop=2479.6s speaker_SPEAKER_03
# start=2480.1s stop=2480.3s speaker_SPEAKER_02
# start=2480.3s stop=2480.5s speaker_SPEAKER_03
# start=2480.5s stop=2480.6s speaker_SPEAKER_02
# start=2480.7s stop=2483.3s speaker_SPEAKER_02
# start=2483.9s stop=2485.5s speaker_SPEAKER_02
# start=2484.3s stop=2486.0s speaker_SPEAKER_00
# start=2486.1s stop=2487.3s speaker_SPEAKER_02
# start=2486.1s stop=2487.3s speaker_SPEAKER_00
# start=2487.9s stop=2490.3s speaker_SPEAKER_02
# start=2490.8s stop=2499.3s speaker_SPEAKER_02
# start=2492.6s stop=2492.6s speaker_SPEAKER_00
# start=2492.6s stop=2498.2s speaker_SPEAKER_03
# start=2499.5s stop=2499.8s speaker_SPEAKER_03
# start=2501.1s stop=2503.6s speaker_SPEAKER_03
# start=2501.4s stop=2502.4s speaker_SPEAKER_02
# start=2502.4s stop=2502.4s speaker_SPEAKER_00
# start=2505.3s stop=2506.5s speaker_SPEAKER_03
# start=2507.3s stop=2507.8s speaker_SPEAKER_03
# start=2508.5s stop=2514.0s speaker_SPEAKER_03
# start=2510.8s stop=2510.9s speaker_SPEAKER_00
# start=2512.1s stop=2512.2s speaker_SPEAKER_04
# start=2512.2s stop=2512.6s speaker_SPEAKER_00
# start=2514.4s stop=2516.8s speaker_SPEAKER_03
# start=2516.5s stop=2518.1s speaker_SPEAKER_00
# start=2519.5s stop=2520.6s speaker_SPEAKER_03
# start=2519.7s stop=2520.5s speaker_SPEAKER_00
# start=2521.1s stop=2523.9s speaker_SPEAKER_00
# start=2526.1s stop=2527.5s speaker_SPEAKER_00
# start=2528.1s stop=2528.2s speaker_SPEAKER_00
# start=2528.2s stop=2531.1s speaker_SPEAKER_02
# start=2528.3s stop=2529.8s speaker_SPEAKER_00
# start=2531.2s stop=2531.2s speaker_SPEAKER_02
# start=2531.2s stop=2531.9s speaker_SPEAKER_00
# start=2531.2s stop=2533.6s speaker_SPEAKER_02
# start=2533.0s stop=2535.5s speaker_SPEAKER_00
# start=2533.6s stop=2533.7s speaker_SPEAKER_03
# start=2535.8s stop=2541.7s speaker_SPEAKER_03
# start=2535.9s stop=2536.6s speaker_SPEAKER_00
# start=2542.0s stop=2544.5s speaker_SPEAKER_03
# start=2544.5s stop=2545.9s speaker_SPEAKER_03
# start=2545.2s stop=2545.9s speaker_SPEAKER_02
# start=2546.6s stop=2546.6s speaker_SPEAKER_03
# start=2546.6s stop=2548.3s speaker_SPEAKER_02
# start=2548.4s stop=2553.8s speaker_SPEAKER_02
# start=2554.2s stop=2554.8s speaker_SPEAKER_02
# start=2555.4s stop=2556.9s speaker_SPEAKER_00
# start=2557.6s stop=2560.1s speaker_SPEAKER_02
# start=2560.7s stop=2562.0s speaker_SPEAKER_00
# start=2560.9s stop=2562.2s speaker_SPEAKER_02
# start=2562.0s stop=2562.1s speaker_SPEAKER_03
# start=2562.5s stop=2563.7s speaker_SPEAKER_02
# start=2563.9s stop=2563.9s speaker_SPEAKER_00
# start=2563.9s stop=2564.3s speaker_SPEAKER_03
# start=2564.8s stop=2564.8s speaker_SPEAKER_02
# start=2564.8s stop=2565.4s speaker_SPEAKER_03
# start=2565.4s stop=2565.6s speaker_SPEAKER_02
# start=2565.6s stop=2565.7s speaker_SPEAKER_03
# start=2565.7s stop=2565.7s speaker_SPEAKER_02
# start=2565.8s stop=2566.6s speaker_SPEAKER_02
# start=2566.9s stop=2568.3s speaker_SPEAKER_02
# start=2568.6s stop=2569.5s speaker_SPEAKER_02
# start=2569.8s stop=2570.4s speaker_SPEAKER_02
# start=2570.9s stop=2571.9s speaker_SPEAKER_02
# start=2571.4s stop=2573.7s speaker_SPEAKER_00
# start=2575.7s stop=2576.9s speaker_SPEAKER_02
# start=2577.6s stop=2581.7s speaker_SPEAKER_02
# start=2582.3s stop=2584.3s speaker_SPEAKER_03
# start=2584.3s stop=2584.3s speaker_SPEAKER_02
# start=2584.6s stop=2585.0s speaker_SPEAKER_03
# start=2585.0s stop=2585.8s speaker_SPEAKER_02
# start=2586.7s stop=2586.7s speaker_SPEAKER_03
# start=2586.7s stop=2587.3s speaker_SPEAKER_00
# start=2586.8s stop=2588.4s speaker_SPEAKER_02
# start=2587.3s stop=2587.3s speaker_SPEAKER_03
# start=2588.7s stop=2589.5s speaker_SPEAKER_02
# start=2590.0s stop=2590.7s speaker_SPEAKER_02
# start=2590.9s stop=2593.0s speaker_SPEAKER_02
# start=2592.1s stop=2592.9s speaker_SPEAKER_00
# start=2593.0s stop=2593.4s speaker_SPEAKER_00
# start=2593.4s stop=2598.3s speaker_SPEAKER_02
# start=2593.6s stop=2594.0s speaker_SPEAKER_00
# start=2594.4s stop=2596.1s speaker_SPEAKER_00
# start=2599.2s stop=2600.1s speaker_SPEAKER_02
# start=2600.4s stop=2601.7s speaker_SPEAKER_02
# start=2602.2s stop=2605.0s speaker_SPEAKER_02
# start=2603.6s stop=2608.1s speaker_SPEAKER_03
# start=2610.9s stop=2614.0s speaker_SPEAKER_03
# start=2613.5s stop=2613.6s speaker_SPEAKER_00
# start=2613.6s stop=2613.9s speaker_SPEAKER_04
# start=2613.9s stop=2614.0s speaker_SPEAKER_00
# start=2614.0s stop=2614.0s speaker_SPEAKER_04
# start=2614.0s stop=2614.1s speaker_SPEAKER_00
# start=2615.2s stop=2616.7s speaker_SPEAKER_00
# start=2615.3s stop=2616.4s speaker_SPEAKER_04
# start=2617.5s stop=2621.5s speaker_SPEAKER_00
# start=2622.3s stop=2623.1s speaker_SPEAKER_02
# start=2623.1s stop=2623.7s speaker_SPEAKER_00
# start=2623.1s stop=2623.7s speaker_SPEAKER_02
# start=2623.7s stop=2623.7s speaker_SPEAKER_02
# start=2623.7s stop=2624.0s speaker_SPEAKER_00
# start=2624.0s stop=2624.2s speaker_SPEAKER_02
# start=2624.2s stop=2624.4s speaker_SPEAKER_00
# start=2624.3s stop=2624.7s speaker_SPEAKER_02
# start=2624.7s stop=2624.8s speaker_SPEAKER_00
# start=2624.8s stop=2624.9s speaker_SPEAKER_02
# start=2624.9s stop=2625.0s speaker_SPEAKER_00
# start=2625.0s stop=2625.2s speaker_SPEAKER_02
# start=2625.2s stop=2625.4s speaker_SPEAKER_00
# start=2625.4s stop=2625.4s speaker_SPEAKER_02
# start=2625.4s stop=2625.5s speaker_SPEAKER_00
# start=2625.5s stop=2629.5s speaker_SPEAKER_02
# start=2627.4s stop=2628.6s speaker_SPEAKER_00
# start=2628.8s stop=2631.4s speaker_SPEAKER_00
# start=2636.0s stop=2638.7s speaker_SPEAKER_00
# start=2638.0s stop=2638.9s speaker_SPEAKER_01
# start=2639.4s stop=2640.4s speaker_SPEAKER_00
# start=2640.9s stop=2642.3s speaker_SPEAKER_00
# start=2643.7s stop=2646.0s speaker_SPEAKER_00
# start=2646.0s stop=2646.0s speaker_SPEAKER_03
# start=2646.0s stop=2646.5s speaker_SPEAKER_00
# start=2646.5s stop=2646.7s speaker_SPEAKER_03
# start=2646.7s stop=2647.0s speaker_SPEAKER_00
# start=2647.0s stop=2649.8s speaker_SPEAKER_03
# start=2650.2s stop=2650.3s speaker_SPEAKER_03
# start=2650.3s stop=2650.7s speaker_SPEAKER_00
# start=2650.7s stop=2652.0s speaker_SPEAKER_03
# start=2652.0s stop=2652.3s speaker_SPEAKER_00
# start=2653.0s stop=2653.0s speaker_SPEAKER_03
# start=2653.0s stop=2654.0s speaker_SPEAKER_00
# start=2655.1s stop=2659.3s speaker_SPEAKER_00
# start=2657.5s stop=2658.1s speaker_SPEAKER_03
# start=2659.7s stop=2663.3s speaker_SPEAKER_00
# start=2665.4s stop=2666.0s speaker_SPEAKER_00
# start=2666.0s stop=2666.1s speaker_SPEAKER_00
# start=2666.7s stop=2667.7s speaker_SPEAKER_00
# start=2673.1s stop=2675.0s speaker_SPEAKER_00
# start=2678.4s stop=2678.5s speaker_SPEAKER_00
# start=2678.5s stop=2678.6s speaker_SPEAKER_02
# start=2678.6s stop=2678.7s speaker_SPEAKER_00
# start=2680.7s stop=2683.4s speaker_SPEAKER_02
# start=2685.1s stop=2685.9s speaker_SPEAKER_02
# start=2687.0s stop=2689.8s speaker_SPEAKER_00
# start=2688.4s stop=2690.6s speaker_SPEAKER_02
# start=2689.8s stop=2690.0s speaker_SPEAKER_00
# start=2690.9s stop=2692.5s speaker_SPEAKER_00
# start=2694.9s stop=2695.0s speaker_SPEAKER_00
# start=2695.0s stop=2695.0s speaker_SPEAKER_00
# start=2695.6s stop=2696.3s speaker_SPEAKER_00
# start=2696.3s stop=2696.3s speaker_SPEAKER_03
# start=2699.0s stop=2702.2s speaker_SPEAKER_03
# start=2699.8s stop=2700.6s speaker_SPEAKER_00
# start=2702.4s stop=2704.5s speaker_SPEAKER_00
# start=2704.7s stop=2706.5s speaker_SPEAKER_03
# start=2706.5s stop=2707.4s speaker_SPEAKER_00

# %% [markdown]
# ### 1.1.1.1 Save the CSV file for the Selected Speaker
# After printing the list of speakers, it is necessary to identify the speaker corresponding to the video under analysis. In this case, this step was performed manually by comparing the speaker annotations until they matched the speech of the subject in the video. This process was necessary because, in the dataset used, there are three individuals speaking within the same audio file.
#
# Once the corresponding speaker is identified, the following code allows saving the speech annotations by requiring three parameters:
# 1. The path to save the CSV file.
# 2. The identified speaker whose annotations need to be saved.
# 3. A diarization object returned by the Pyannote model.

# %%
# Function to convert seconds into hh:mm:ss.sss format
def seconds_to_timestamp(seconds):
    t = timedelta(seconds=seconds)
    total_seconds = int(t.total_seconds())
    milliseconds = int((t.total_seconds() - total_seconds) * 1000)
    hours, remainder = divmod(total_seconds, 3600) # 3600 seconds = 1 hour
    minutes, seconds = divmod(remainder, 60) # 60 seconds = 1 minute
    return f"{hours:02}:{minutes:02}:{seconds:02}.{milliseconds:03}"

# Function to save the annotations of a specific speaker to a CSV file in ELAN format
def save_annotation_speech(file_csv,selected_speaker,diarization):
    # Open a CSV file to write the results
    with open(file_csv, "w", newline="") as csvfile:
        csvwriter = csv.writer(csvfile)
        # Write the header
        csvwriter.writerow(["Event", "Nan", "Start_time", "Start_seconds", "End_time", "End_seconds", "Duration", "Duration_seconds", "Tools/Speaker"])
        # Iterate through the diarization results
        for turn, _, speaker in diarization.itertracks(yield_label=True):
            start_time = seconds_to_timestamp(turn.start)
            end_time = seconds_to_timestamp(turn.end)
            duration = turn.end - turn.start
            
            if speaker == selected_speaker and duration > 1: 
                 # Write the row to the CSV file
                csvwriter.writerow([
                    "speech", "Nan",
                    start_time, f"{turn.start:.3f}",
                    end_time, f"{turn.end:.3f}",
                    seconds_to_timestamp(duration), f"{duration:.3f}",
                    f"{speaker}"
                ])

save_annotation_speech("Speech_annotations.csv", "SPEAKER_00", diarization)

# %% [markdown]
# ### 1.1.1.2 Removal of Overlapping Speech Annotations
# Finally, the speech annotations are compared with the existing ones, and any speech annotations overlapping with the existing ones are removed. Additionally, the annotations are merged and concatenated with the other existing annotations into a single CSV file.

# %%
# Add speech annotations to the file of existing annotations, removing speech annotations that overlap with the existing ones
import pandas as pd
from datetime import timedelta
#  Function to check overlapping between two intervals
def is_overlapping(start1, end1, start2, end2):
    return max(start1, start2) < min(end1, end2)                         

# Function to convert seconds into hh:mm:ss.sss format
def seconds_to_timestamp(seconds):
    t = timedelta(seconds=seconds)
    total_seconds = int(t.total_seconds())
    milliseconds = int((t.total_seconds() - total_seconds) * 1000)
    hours, remainder = divmod(total_seconds, 3600) # 3600 seconds = 1 hour
    minutes, seconds = divmod(remainder, 60) # 60 seconds = 1 minute
    return f"{hours:02}:{minutes:02}:{seconds:02}.{milliseconds:03}"

def add_speech_annotations(existing_annotation,speech_annotation, output_csv):
    # Load existing annotations
    existing_df = pd.read_csv(existing_annotation)
    existing_interval = []
    existing_df["Start_seconds"] = pd.to_numeric(existing_df["Start_seconds"], errors='coerce') # Convert to float
    existing_df["End_seconds"] = pd.to_numeric(existing_df["End_seconds"], errors='coerce')
    for _, row in existing_df.iterrows():
        existing_interval.append((row["Start_seconds"], row["End_seconds"]))

    # Load speech annotations
    speech_df = pd.read_csv(speech_annotation)
    speech_interval = []
    speech_df["Start_seconds"] = pd.to_numeric(speech_df["Start_seconds"], errors='coerce')
    speech_df["End_seconds"] = pd.to_numeric(speech_df["End_seconds"], errors='coerce')
    for _, row in speech_df.iterrows():
        speech_interval.append((row["Start_seconds"], row["End_seconds"]))

    # Filter speech annotations that do not overlap with existing annotations
    filtered_speech = []
    for start, end in speech_interval:
        overlap_found = False
        start_check = start
        end_check = end
        for existing_start, existing_end in existing_interval:
            if is_overlapping(start_check, end_check, existing_start, existing_end):
                overlap_found = True
                break
        if not overlap_found:
            filtered_speech.append((start, end))

    # Add filtered speech annotations to the file with existing annotations
    with open(output_csv, "w") as csvfile:
        csvfile.write("Event,Nan,Start_time,Start_seconds,End_time,End_seconds,Duration,Duration_seconds,Tools/Speaker\n") # Save header to CSV
        for start, end in filtered_speech:
            csvfile.write(f'speech,,{seconds_to_timestamp(start)},{start:.3f},{seconds_to_timestamp(end)},{end:.3f},{seconds_to_timestamp(end - start)},{(end-start):.3f},""\n')
        for _, row in existing_df.iterrows():
            csvfile.write(f'{row["Event"]},,{row["Start_time"]},{row["Start_seconds"]},{row["End_time"]},{row["End_seconds"]},{row["Duration"]},{row["Duration_seconds"]},{row["Tools/Speaker"]}\n')

add_speech_annotations("Annotations_video.csv", "Speech_annotations.csv", "Annotations_video_Speech.csv")

# %% [markdown]
# ### 1.1.2 Creating the "Other" Annotation
# - Creation of "**other**" annotations (Before doing this, ensure you have a CSV file containing all the video annotations; this way, the created annotations will not overwrite the existing ones).
# - The "other" annotation is created 1 second after the end of the current annotation, but only if its duration is between **1 and 3 seconds**, with a maximum of **50** annotations for video.
#     - The maximum number of annotations to save can be adjusted based on the dataset distribution. To achieve a balanced dataset, it is ideal to avoid having too many annotations for a single class and instead aim for a similar number across all classes.

# %%
import pandas as pd
from datetime import timedelta

# Function to convert seconds into hh:mm:ss.sss format
def seconds_to_timestamp(seconds):
    t = timedelta(seconds=seconds)
    total_seconds = int(t.total_seconds())
    milliseconds = int((t.total_seconds() - total_seconds) * 1000)
    hours, remainder = divmod(total_seconds, 3600) # 3600 seconds = 1 hour
    minutes, seconds = divmod(remainder, 60) # 60 seconds = 1 minute
    return f"{hours:02}:{minutes:02}:{seconds:02}.{milliseconds:03}"

# Function to add "other" annotations
def add_other_annotations(annotations_file, output_csv):
    #  Read the annotations
    df = pd.read_csv(annotations_file)
    df["Start_seconds"] = pd.to_numeric(df["Start_seconds"], errors='coerce')
    df["End_seconds"] = pd.to_numeric(df["End_seconds"], errors='coerce')
    print(f"Annotations data loaded with shape: {df.shape}")

    other_annotations = []
    other_count = 0
    # Iterate through annotations to identify gaps between end and start times
    for i in range(len(df) - 1): # Does not consider the last annotation (in case it coincides with the end of the video)
        current_end = df.iloc[i]["End_seconds"]
        next_start = df.iloc[i + 1]["Start_seconds"]
        
       # Calculate the gap duration, considering 1 second after the end of the current annotation
        start_other = current_end + 1
        gap_duration = next_start - start_other 

        # If the gap is at least 1 second, create "other" annotations
        if gap_duration >= 1:
            other_duration  = min(gap_duration, 3)  # Limit the duration to a maximum of 3 seconds
            other_end = start_other + other_duration 
            
            for j in range(len(df)):
                existing_start = df.iloc[j]["Start_seconds"]
                existing_end = df.iloc[j]["End_seconds"]
                
                # Check if the new "other" annotation overlaps with an existing annotation
                if start_other < existing_end and other_end > existing_start:
                    other_end = min(other_end , existing_start) # Truncate "other" before the annotation
                    other_duration = other_end - start_other
                    break

            if other_duration  < 1: # Skip if the duration is less than 1 second
                continue

            # Create the new "other" annotation
            other_annotation = {
                'Event': 'other',
                'Nan': '',
                'Start_time': seconds_to_timestamp(start_other),
                'Start_seconds': round(start_other, 3),
                'End_time': seconds_to_timestamp(other_end),
                'End_seconds': round(other_end, 3),
                'Duration': seconds_to_timestamp(other_duration),
                'Duration_seconds': round(other_duration, 3),
                'Tools/Speaker': ''
            }
            if other_count < 50: # Limit the number of "other" annotations to 50. TODO: Change this value based on the balance of the dataset
                other_count += 1
                other_annotations.append(other_annotation)
            else:
                break

    # Add the new "other" annotations to the original dataframe and sort by start time
    other_df = pd.DataFrame(other_annotations)
    combined_df = pd.concat([df, other_df], ignore_index=True)
    combined_df = combined_df.sort_values(by="Start_seconds").reset_index(drop=True)
    combined_df.to_csv(output_csv, index=False)
    print(f"Saved extended annotations with 'other' annotations to {output_csv}")

# Aggiungi le annotazioni "other"
add_other_annotations("Annotations_video_Speech.csv","Annotations_video_Speech&Other.csv")
# Out:
# Annotations data loaded with shape: (310, 9)
# Saved extended annotations with 'other' annotations to Annotations_video_Speech&Other.csv

# %% [markdown]
# # 2: Data Extraction from Videos
#
# To prepare the input data for the model, it is necessary to extract features from videos while considering annotations. The extracted features are divided into two main categories:
#
# ## 2.1 Keypoints
# Keypoints represent the 3D coordinates of specific body points, selected in this project from facial, hand, and body landmarks.
#
# ### Normalization
# To eliminate influences caused by camera framing, video resolution, or subject size, the keypoints undergo a normalization process:
# - **Anchor-based Normalization**:
#   - Facial keypoints are normalized relative to the nose as a fixed reference point.
#   - Hand keypoints are normalized using the wrists as reference points.
# - **Body Size-based Normalization**:
#   - Keypoints are normalized by dividing their coordinates based on the ratio between head height and torso width.
#
# ## 2.2 Descriptors
# Descriptors represent the distances between specific keypoints. These are carefully chosen to provide the model with relevant information for distinguishing actions.
#
# ---
#
# ## 2.3 Feature Extraction Process
# Features are extracted within the time intervals defined by video annotations. Annotations are padded with additional frames at the end to ensure that the total frame count matches the sequence length required by the model.
#
# ### Validation Check
# Data is saved only if the annotations have more than 50% of frames where keypoints are successfully extracted. If not, both the data and the corresponding annotation are discarded. This precaution addresses situations where MediaPipe fails to extract keypoints due to occluded body parts, resulting in null data. This approach ensures that only reliable data is used for model training.
#
# ---
#
# ## 2.4 Augmentation
# Features are extracted twice for each video:
# 1. Using the original video.
# 2. Using a horizontally flipped version of the video.
#
# This augmentation is necessary because most subjects in the dataset predominantly use their right hand. Without flipping, the model may struggle to classify actions performed with the left hand. However, this step can be disabled if not required.

# %%
import cv2
import mediapipe as mp
import csv
import pandas as pd
import numpy as np

# Function to normalize keypoints
def normalize_landmarks(landmarks, nose, height_width_ratio):
    # List of selected face keypoints to extract
    face_keypoint_indices = [1, 159, 386, 78, 95, 88, 178, 87, 14, 317, 402, 318, 324, 308, 191, 80, 81, 82, 13, 312, 311, 310, 415,
                         474, 475, 476, 477, 469, 470, 471, 472, 33, 133, 362, 61, 199, 263, 291]
    keypoints = []
    nose_x, nose_y, nose_z= nose.x, nose.y,nose.z
    keypoints.append([float(nose_x/height_width_ratio), float(nose_y/height_width_ratio),float(nose_z/height_width_ratio), 1]) 
    for idx in face_keypoint_indices:
        if idx == 1:
            continue
        keyp = landmarks[idx]
        x, y,z = keyp.x, keyp.y,keyp.z
        keypoints.append([float((x - nose_x)/height_width_ratio), float((y - nose_y)/height_width_ratio),float((z - nose_z)/height_width_ratio),idx])
    return keypoints

# Function to extract keypoints from face, hands and pose
def extract_keypoints(face_landmarks, hand_landmarks, pose_landmarks):
    
    face_keypoints = []
    height_width_ratio = 0
    hand_keypoints = {
            'left_hand': [],
            'right_hand': []
    }
    if face_landmarks and pose_landmarks: # Skip frame where there are no face and pose landmarks
        nose = face_landmarks[1]
        # Calculate the height/width ratio useful for normalization
        left_shoulder = pose_landmarks.landmark[11]  
        right_shoulder = pose_landmarks.landmark[12] 
        # Calculate the euclidean distance between the shoulders
        shoulder_width = np.linalg.norm(np.array([left_shoulder.x, left_shoulder.y,left_shoulder.z]) - np.array([right_shoulder.x, right_shoulder.y,right_shoulder.z])) 
        left_eye = face_landmarks[33]
        right_eye = face_landmarks[263]
        chin = face_landmarks[199]
        eye_middle = (np.array([left_eye.x, left_eye.y,left_eye.z]) + np.array([right_eye.x, right_eye.y,right_eye.z])) / 2
        face_height = np.linalg.norm(np.array([eye_middle[0], eye_middle[1],eye_middle[2]]) - np.array([chin.x, chin.y,chin.z]))
        height_width_ratio = face_height / shoulder_width
        # Normalize the keypoints
        face_keypoints = normalize_landmarks(face_landmarks, nose, height_width_ratio)

        # Extract the left and right wrist landmarks from the pose landmarks
        left_wrist = pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.LEFT_WRIST]
        right_wrist = pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.RIGHT_WRIST]

        # Extract the hand landmarks and normalize them
        hand_keypoints = {
            'left_hand': [[float((lm.x-left_wrist.x)/height_width_ratio), float((lm.y-left_wrist.y)/height_width_ratio),float((lm.z - left_wrist.z)/height_width_ratio),index] for index,lm in enumerate(hand_landmarks.get('left_hand', []))],
            'right_hand': [[float((lm.x-right_wrist.x)/height_width_ratio), float((lm.y-right_wrist.y)/height_width_ratio),float((lm.z-right_wrist.z)/height_width_ratio),index] for index,lm in enumerate(hand_landmarks.get('right_hand', []))]
        }
    return face_keypoints, hand_keypoints, height_width_ratio

# Function to process the video and extract keypoints
def process_video(video_file, output_csv, annotation_intervals, flip_bool, window_size):
    cap = cv2.VideoCapture(video_file)
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    # Create the output CSV file
    with open(output_csv, mode='w', newline='') as file:
        writer = csv.writer(file)
        # Header for the CSV file
        writer.writerow(['timestamp', 'face_keypoints', 'left_hand_keypoints', 'right_hand_keypoints','left_wrist','right_wrist', 
                         'mouth_polseSX_dist','mouth_polseDX_dist', 'lip_up_down_dist','mouth_left_right_dist','height_width_ratio','dist_nose_mouth_left',
                         'dist_nose_mouth_right','nose_polseSX_dist','nose_polseDX_dist','dist_nose_mouth_left2','dist_nose_mouth_right2','dist_mouth_eye_center',
                         'count','label'])
        
        # Set the minimum detection and tracking confidence for MediaPipe solutions
        MIN_DETECTION_CONFIDENCE = 0.5
        MIN_TRACKING_CONFIDENCE = 0.5

        # Initialize MediaPipe solutions for face mesh, hands and pose
        with mp.solutions.face_mesh.FaceMesh(refine_landmarks=True, min_detection_confidence=MIN_DETECTION_CONFIDENCE, min_tracking_confidence=MIN_TRACKING_CONFIDENCE) as face_mesh, \
             mp.solutions.hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=MIN_DETECTION_CONFIDENCE) as hands, \
             mp.solutions.pose.Pose(min_detection_confidence=MIN_DETECTION_CONFIDENCE, min_tracking_confidence=MIN_TRACKING_CONFIDENCE) as pose:
            
            for start_time, end_time, event in annotation_intervals:
                frame_csv = []
                count_frame_good = 0
                # Calculate the start and end frames
                start_frame = int(start_time * fps)
                end_frame = int(end_time * fps)
                
                # Set the video to the starting frame of the interval of the annotation
                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                # Calculate the number of frames in the interval
                duration = (end_frame - start_frame) + 1
                
                if duration < window_size: #Padding to have window_size frame
                    end_frame = end_frame + (window_size - duration)
                elif duration % window_size != 0: #Padding to have a multiple of window_size frames
                    end_frame = end_frame + (window_size - (duration % window_size))
                
                count_frame = 1
                for frame_number in range(start_frame, end_frame + 1):
                    ret, frame = cap.read()
                    if not ret:
                        break
                    
                    if flip_bool == True: # Flip the frame horizontally if specified
                        frame = cv2.flip(frame,1)
                    # Calculate the current timestamp
                    timestamp = frame_number / fps
                    # Process the image
                    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

                    # Extract face, hand and pose landmarks
                    face_mesh_results = face_mesh.process(image)
                    hands_results = hands.process(image)
                    pose_results = pose.process(image)

                    # Extract the face landmarks (if present)
                    face_landmarks = face_mesh_results.multi_face_landmarks[0].landmark \
                        if face_mesh_results.multi_face_landmarks else None

                    # Extract the hand landmarks (if present)
                    hand_landmarks = {}
                    if hands_results.multi_hand_landmarks:
                        for idx, hand_landmark in enumerate(hands_results.multi_hand_landmarks):
                            hand_type = 'left_hand' if hands_results.multi_handedness[idx].classification[0].label == 'Left' else 'right_hand'
                            hand_landmarks[hand_type] = hand_landmark.landmark

                    # Extract the pose landmarks (if present)  
                    pose_landmarks = pose_results.pose_landmarks if pose_results.pose_landmarks else None
                
                    # Extract normalized keypoints
                    face_keypoints, hand_keypoints, height_width_ratio = extract_keypoints(face_landmarks, hand_landmarks, pose_landmarks)

                    # Extract distances
                    mouth_polseSX_dist = 0
                    mouth_polseDX_dist = 0
                    lip_up_down_dist = 0
                    mouth_left_right_dist = 0
                    dist_nose_mouth_left = 0
                    dist_nose_mouth_right = 0
                    nose_polseSX_dist = 0
                    nose_polseDX_dist = 0
                    dist_nose_mouth_left2 = 0
                    dist_nose_mouth_right2 = 0
                    dist_mouth_eye_center = 0
                    left_wrist = None
                    right_wrist = None
                    
                    if pose_results.pose_landmarks:
                        # Get wrist landmarks (from Pose landmarks)
                        left_wrist = pose_results.pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.LEFT_WRIST]
                        left_wrist_point = np.array([left_wrist.x, left_wrist.y,left_wrist.z])
                        right_wrist = pose_results.pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.RIGHT_WRIST]
                        right_wrist_point = np.array([right_wrist.x, right_wrist.y,right_wrist.z])
                        
                        if face_mesh_results.multi_face_landmarks:
                            face_landmarks = face_mesh_results.multi_face_landmarks[0]
                            mouth_x = (face_landmarks.landmark[13].x + face_landmarks.landmark[14].x) / 2
                            mouth_y = (face_landmarks.landmark[13].y + face_landmarks.landmark[14].y) / 2
                            mouth_z = (face_landmarks.landmark[13].z + face_landmarks.landmark[14].z) / 2
                            mouth_point = np.array([mouth_x, mouth_y,mouth_z])
                            nose_point = np.array([face_landmarks.landmark[1].x , face_landmarks.landmark[1].y , face_landmarks.landmark[1].z ])
                            
                            # Distance between the mouth and wrists
                            mouth_polseSX_dist = np.linalg.norm(left_wrist_point - mouth_point)
                            mouth_polseDX_dist = np.linalg.norm(right_wrist_point - mouth_point)

                            # Distance between upper and lower lip
                            lip_up = np.array([face_landmarks.landmark[13].x, face_landmarks.landmark[13].y, face_landmarks.landmark[13].z])
                            lip_down = np.array([face_landmarks.landmark[14].x, face_landmarks.landmark[14].y, face_landmarks.landmark[14].z])
                            lip_up_down_dist = np.linalg.norm(lip_up - lip_down)

                            # Distance between the left and right corners of the mouth
                            mouth_left = np.array([face_landmarks.landmark[78].x, face_landmarks.landmark[78].y, face_landmarks.landmark[78].z])
                            mouth_right = np.array([face_landmarks.landmark[308].x, face_landmarks.landmark[308].y, face_landmarks.landmark[308].z])

                            # Distance between the nose and the corners of the mouth
                            dist_nose_mouth_left = np.linalg.norm(nose_point - mouth_left)
                            dist_nose_mouth_right = np.linalg.norm(nose_point - mouth_right)
                        
                            # Distance between the nose and the wrists
                            nose_polseSX_dist = np.linalg.norm(left_wrist_point - nose_point)
                            nose_polseDX_dist = np.linalg.norm(right_wrist_point - nose_point)
                            
                            # Set a specific point for the corners of the mouth (left and right)
                            mouth_left2 = np.array([face_landmarks.landmark[61].x, face_landmarks.landmark[61].y, face_landmarks.landmark[61].z])
                            mouth_right2 = np.array([face_landmarks.landmark[291].x, face_landmarks.landmark[291].y, face_landmarks.landmark[291].z])

                            # Distance between the nose and the specific corners of the mouth (left and right)
                            dist_nose_mouth_left2 = np.linalg.norm(nose_point - mouth_left2)
                            dist_nose_mouth_right2 = np.linalg.norm(nose_point - mouth_right2)
                    
                            # Distance between the specific corners of the mouth (left and right)
                            mouth_left_right_dist = np.linalg.norm(mouth_left2 - mouth_right2)

                            # Set a specific point for the eyes (left and right)
                            left_eye = np.array([face_landmarks.landmark[133].x , face_landmarks.landmark[133].y , face_landmarks.landmark[133].z ])
                            right_eye = np.array([face_landmarks.landmark[362].x , face_landmarks.landmark[362].y , face_landmarks.landmark[362].z])

                            # Distance vertical between the center of the eyes and the center of the mouth
                            center_eye = np.array((left_eye + right_eye)/2)
                            mouth_center = np.array((mouth_left2 + mouth_right2)/2)
                            dist_mouth_eye_center = np.linalg.norm(mouth_center - center_eye)
                            
                    if face_keypoints != []:
                        count_frame_good += 1

                    if height_width_ratio != 0:
                        left_wrist = [float(left_wrist.x/height_width_ratio), float(left_wrist.y/height_width_ratio),float(left_wrist.z/height_width_ratio)] if left_wrist else [0, 0, 0] 
                        right_wrist = [float(right_wrist.x/height_width_ratio), float(right_wrist.y/height_width_ratio),float(right_wrist.z/height_width_ratio)] if right_wrist else [0, 0, 0]
                    else:
                        left_wrist = [left_wrist.x, left_wrist.y,left_wrist.z] if left_wrist else [0, 0, 0] 
                        right_wrist = [right_wrist.x, right_wrist.y,right_wrist.z] if right_wrist else [0, 0, 0]
                            
                    frame_csv.append([timestamp, face_keypoints, hand_keypoints['left_hand'], hand_keypoints['right_hand'],left_wrist, right_wrist,mouth_polseSX_dist,mouth_polseDX_dist,lip_up_down_dist,mouth_left_right_dist,height_width_ratio,dist_nose_mouth_left,dist_nose_mouth_right,nose_polseSX_dist,nose_polseDX_dist,dist_nose_mouth_left2,dist_nose_mouth_right2,dist_mouth_eye_center,count_frame,event])
                    count_frame += 1
                # Save only if the majority of frames are good
                if count_frame_good >= (len(frame_csv) / 2): 
                    for frame in frame_csv:
                        writer.writerow(frame)
    cap.release()

# Main function to extract data from the video 
def extract_data(annotations_path, video_path, output_csv):
    window_size = 21 # TODO: Change in base of the sequence length of the model
    annotations_df = pd.read_csv(annotations_path)
    annotation_intervals = []
    speech_count = 0
    for _, row in annotations_df.iterrows():
        # Some conditions to filter the annotations, optional if the csv file of annotations is already filtered and cleaned 
        if row['Event'] == 'speech': 
            speech_count += 1
            if speech_count > 50: # TODO: Change this value based on the balance of the dataset
                continue
        if row['Event'] == 'mouth_open': # In this case, this annotation class is ignored
            continue
        annotation_intervals.append((row['Start_seconds'], row['End_seconds'], row['Event']))
    
    # Process the video
    print(f"Processing video: {video_path}")
    process_video(video_path, output_csv, annotation_intervals, False, window_size)

    # Process the video with flipped frames
    print(f"Processing video_flip: {video_path}")
    process_video(video_path, output_csv.replace(".csv", "_flip.csv"), annotation_intervals, True, window_size)

extract_data("Annotations_video_Speech&Other.csv", "01_1.mp4", "01_keypoints.csv")
# Out:
# Processing video: 01_1.mp4

# %% [markdown]
# # 3: LSTM Model
#
# In this project, an LSTM model was used for sequential data processing. This model is ideal due to its ability to preserve information over time intervals, making it particularly suitable for the classification of actions that unfold over time.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import mediapipe as mp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, LayerNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score, confusion_matrix
from tensorflow.keras.models import load_model
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 3.1: Load the Data to Provide as Input to the Model
#
# First, the data previously extracted from the CSV files must be loaded to begin training the model.
# The code shown applies to a single video.

# %%
# Function to read the keypoints from the CSV file
def read_keypoints(file_path):
    df = pd.read_csv(file_path)    
    # Convert strings to lists for columns with non-empty values
    df["face_keypoints"] = df["face_keypoints"].apply(lambda x: eval(x) if isinstance(x, str) else []) 
    df["left_hand_keypoints"] = df["left_hand_keypoints"].apply(lambda x: eval(x) if isinstance(x, str) else [])
    df["right_hand_keypoints"] = df["right_hand_keypoints"].apply(lambda x: eval(x) if isinstance(x, str) else [])
    df["left_wrist"] = df["left_wrist"].apply(lambda x: eval(x) if isinstance(x, str) else [])
    df["right_wrist"] = df["right_wrist"].apply(lambda x: eval(x) if isinstance(x, str) else [])
    
    # Convert the columns to numeric format
    columns = ["timestamp", "count", "mouth_polseSX_dist", "mouth_polseDX_dist", "lip_up_down_dist", 
        "mouth_left_right_dist", "height_width_ratio", "dist_nose_mouth_left", 
        "dist_nose_mouth_right", "nose_polseSX_dist", "nose_polseDX_dist", 
        "dist_nose_mouth_left2", "dist_nose_mouth_right2", "dist_mouth_eye_center"]    
    for col in columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    print(f"Keypoints data loaded with shape: {df.shape}")
    return df

# Function to map annotations to keypoints extracted from the video
def assign_labels_to_keypoints(keypoints_df, window_size):
    sequences = []
    labels = []
    relevant_keypoints = []
    action_label=""
    face_keypoint_indices = [1, 159, 386, 78, 95, 88, 178, 87, 14, 317, 402, 318, 324, 308, 191, 80, 81, 82, 13, 312, 311, 310, 415, 
                             474, 475, 476, 477, 469, 470, 471, 472, 33, 133, 362, 61, 199, 263, 291]
    hand_keypoint_indices = list(range(21))  # 21 keypoints per hand
    
    for _, row in keypoints_df.iterrows():
        if (row["label"] == "mouth_open"): # Skip this annotation class, optional if the csv file of annotations is already filtered and cleaned
            continue

        # Add face keypoints
        face_keypoint=[]
        if len(row["face_keypoints"]) == 0: # If there are no face keypoints, add null coordinates (0,0,0) for each keypoint
            for idx in face_keypoint_indices:
                face_keypoint.append([0, 0,0])
        else: # If there are face keypoints, extract them, of some of them are missing, add null coordinates (0,0,0) 
            keyp_found=False
            for idx in face_keypoint_indices:
                for keypoint in row["face_keypoints"]:
                    if keypoint[3] == idx:
                        face_keypoint.append(keypoint[0:3])# 
                        keyp_found=True
                        break
                if not keyp_found:
                    face_keypoint.append([0, 0,0])
        
        # Flatten the face keypoints
        face_keypoints_flat = np.array(face_keypoint,dtype='float32').ravel()    

        left_hand=[]
        right_hand=[]
        
        # Add left hand and right hand keypoints, if there are no keypoints, add null coordinates (0,0,0) for each keypoint
        if len(row["left_hand_keypoints"]) == 0:
            for idx in hand_keypoint_indices:
                left_hand.append([0, 0,0])
        else:
            keyp_found=False
            for idx in hand_keypoint_indices:
                for keypoint in row["left_hand_keypoints"]:
                    if keypoint[3] == idx:
                        left_hand.append(keypoint[0:3])
                        keyp_found=True
                        break
                if not keyp_found:
                    left_hand.append([0, 0,0])

        if len(row["right_hand_keypoints"]) == 0:
            for idx in hand_keypoint_indices:
                right_hand.append([0, 0,0])
        else:
            keyp_found=False
            for idx in hand_keypoint_indices:
                for keypoint in row["right_hand_keypoints"]:
                    if keypoint[3] == idx:
                        right_hand.append(keypoint[0:3])
                        keyp_found=True
                        break
                if not keyp_found:
                    right_hand.append([0, 0,0])

        # Flatten the hand keypoints
        left_hand_flat=np.array(left_hand,dtype='float32').ravel()
        right_hand_flat=np.array(right_hand,dtype='float32').ravel()

        # Flatten the wrist keypoints
        left_wrist = np.array(row["left_wrist"],dtype='float32').ravel()
        right_wrist = np.array(row["right_wrist"],dtype='float32').ravel()
        
        # Save the label of the annotation for the first frame
        if row["count"] % window_size == 1:
            action_label = row["label"]


        # Extract distances and flatten them     
        distances = np.array([row["mouth_polseSX_dist"], row["mouth_polseDX_dist"], row["lip_up_down_dist"], 
                              row["mouth_left_right_dist"], row["dist_nose_mouth_left"], row["dist_nose_mouth_right"],
                              row["nose_polseSX_dist"], row["nose_polseDX_dist"], row["dist_nose_mouth_left2"],row["dist_nose_mouth_right2"],
                              row["dist_mouth_eye_center"]],dtype='float32').ravel() 
        
        # Concatenate keypoints and distances
        combined_data = np.concatenate([
            face_keypoints_flat,
            left_hand_flat,
            right_hand_flat,
            left_wrist,
            right_wrist,
            distances
        ],dtype='float32')
        relevant_keypoints.append(combined_data)
        
        # Save the sequence and the label when the window size is reached
        if row["count"] % window_size == 0:
            sequences.append(relevant_keypoints)
            labels.append(action_label)
            relevant_keypoints = []
            action_label=""
    
    print(f"Sequences: {len(sequences)}, Labels: {len(labels)}")
    return np.array(sequences, dtype='float32'), labels


# Function to prepare data for LSTM model
def prepare_data(keypoints_file,window_size):
    keypoints_df = read_keypoints(keypoints_file) # Read from the CSV file
    sequences,labels = assign_labels_to_keypoints(keypoints_df,window_size) # Assign labels to keypoints
    label_mapping = {"food_to_mouth": 0, "drink_to_mouth": 1, "speech": 2, "other": 3} # Map labels to integers
    labels = np.array([label_mapping[label] for label in labels])
    labels = to_categorical(labels)  # Convert labels to categorical format
    return sequences, labels

# Main function to get data from the CSV files
def get_data(keypoints_csv, keypoints_csv_flip, window_size):    
    all_X = []
    all_y = []

    # Process video
    print(f"Processing video: {keypoints_csv}")
    X, y = prepare_data(keypoints_csv, window_size) 
    all_X.append(X)
    all_y.append(y)

    # Process flipped video
    print(f"Processing video flipped: {keypoints_csv_flip}")
    X, y = prepare_data(keypoints_csv_flip, window_size) 
    all_X.append(X)
    all_y.append(y)

    X = np.concatenate(all_X, axis=0)
    y = np.concatenate(all_y, axis=0)
    return X, y

# Execute the function to get data
X,y = get_data("01_keypoints.csv","01_keypoints_flip.csv", 21)

print(f"X shape: {X.shape}, y shape: {y.shape}")
# Out:
# Processing video: 01_keypoints.csv
# Keypoints data loaded with shape: (12621, 20)
# Sequences: 601, Labels: 601
# Processing video flipped: 01_keypoints_flip.csv
# Keypoints data loaded with shape: (12201, 20)
# Sequences: 581, Labels: 581
# X shape: (1182, 21, 257), y shape: (1182, 4)

# %% [markdown]
# ## 3.2: LSTM Model
#
# Once the data is loaded, the training of the LSTM model begins, which follows the architecture outlined below.

# %%
# Function to build the LSTM model
def build_model(num_classes):
    model = Sequential()
    model.add(LSTM(128, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LayerNormalization())
    model.add(LSTM(48))
    model.add(Dropout(0.30000000000000004))
    model.add(LayerNormalization())
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate=0.00039045908482525734), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Build the model
model = build_model(y.shape[1])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) 

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')

# Save the model
model.save('lstm_model.h5')
print("Model saved as 'lstm_model.h5'")

# %%
# Model evaluation and printing of confusion matrix and classification report
y_pred = model.predict(X_test)
y_pred_classes = y_pred.argmax(axis=1)
y_test_classes = y_test.argmax(axis=1)

# Calculate F-score
f_score = f1_score(y_test_classes, y_pred_classes, average='weighted')
print(f"F-score: {f_score}")

# Print a complete classification report
report = classification_report(y_test_classes, y_pred_classes, target_names=['food_to_mouth', 'drink_to_mouth','speech','other'])
print(report)

# Print the confusion matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=['food_to_mouth', 'drink_to_mouth','speech','other'], yticklabels=['food_to_mouth', 'drink_to_mouth','speech','other'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %% [markdown]
# ## 3.2.1 (Optional) Fine-Tuning with KerasTuner (Hyperband)
# To optimize hyperparameters such as LSTM units, dropout rates, and the learning rate, you can use KerasTuner. With the "Hyperband" algorithm, KerasTuner can explore multiple configurations and return the best one.

# %%
# Fine-tuning with Hyperband

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) 

num_classes = y.shape[1]  # Number of classes in the dataset

# Function to build the LSTM model
def build_model(hp):
    model = Sequential()
    model.add(LSTM(hp.Int('units_lstm_1', min_value=32, max_value=128, step=32), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.2, max_value=0.5, step=0.1)))  # Tasso di dropout variabile
    model.add(LayerNormalization()) 
    model.add(LSTM(hp.Int('units_lstm_2', min_value=16, max_value=64, step=16)))  # Secondo layer LSTM
    model.add(Dropout(hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1)))  # Secondo dropout
    model.add(LayerNormalization()) 
    model.add(Dense(num_classes, activation='softmax'))
    # Ottimizzatore con learning rate variabile
    model.compile(optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-5, max_value=1e-2, sampling='LOG', default=0.005)),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Define the tuner
def run_tuner(x_train, x_test, y_train, y_test):
    tuner = kt.Hyperband(
        build_model,  # Function to build the model
        objective='accuracy', # Metric to optimize
        max_epochs=50,  # Maximum epochs for each trial
        factor=3,  # Factor for Hyperband
        directory = 'tuner_results',  # Directory to save results
        project_name='lstm_tuning',  # Project name
        overwrite=True  # Overwrite previous results
    )
    
    # Execute the tuning process
    tuner.search(x_train, y_train, epochs=50, validation_data=(x_test, y_test)) 

    # Get the best hyperparameters
    best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]
    print(f"Best hyperparameters: {best_hyperparameters.values}")

    # Build the model with the best hyperparameters
    best_model = tuner.hypermodel.build(best_hyperparameters)
    best_model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

    return best_model

# Run the tuner and get the best model
best_model = run_tuner(X_train, X_test, y_train, y_test)

# %% [markdown]
# # 5 Using the Model in Webcam/Video
# Once the model is trained, it can be utilized for real-time video processing or directly with a webcam feed.

# %%
model = load_model('lstm_model.h5')
# Function to extract keypoints from face, hands and pose
def extract_keypoints(face_results, hands_results, pose_results):
    keypoints = []
    face_keypoint_indices = [1, 159, 386, 78, 95, 88, 178, 87, 14, 317, 402, 318, 324, 308, 191, 80, 81, 82, 13, 312, 311, 310, 415, 
                             474, 475, 476, 477, 469, 470, 471, 472, 33, 133, 362, 61, 199, 263, 291]
    hand_keypoint_indices = list(range(21))  # 21 keypoints per hand
    left_hand_keypoints, right_hand_keypoints = [], []  
    height_width_ratio = 0

    # Extract and normalize the keypoints 
    if face_results.multi_face_landmarks and pose_results.pose_landmarks: # Skip frame where there are no face and pose landmarks
        face_landmarks = face_results.multi_face_landmarks[0].landmark
        pose_landmarks = pose_results.pose_landmarks
        nose = face_landmarks[1]
        # Calculate the height/width ratio useful for normalization
        left_shoulder = pose_landmarks.landmark[11]  
        right_shoulder = pose_landmarks.landmark[12] 
        # Calculate the euclidean distance between the shoulders
        shoulder_width = np.linalg.norm(np.array([left_shoulder.x, left_shoulder.y,left_shoulder.z]) - np.array([right_shoulder.x, right_shoulder.y,right_shoulder.z])) 
        left_eye = face_landmarks[33]
        right_eye = face_landmarks[263]
        chin = face_landmarks[199]
        eye_middle = (np.array([left_eye.x, left_eye.y,left_eye.z]) + np.array([right_eye.x, right_eye.y,right_eye.z])) / 2
        face_height = np.linalg.norm(np.array([eye_middle[0], eye_middle[1],eye_middle[2]]) - np.array([chin.x, chin.y,chin.z]))
        height_width_ratio = face_height / shoulder_width
        # Extract the left and right wrist landmarks from the pose landmarks
        left_wrist = pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.LEFT_WRIST]
        right_wrist = pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.RIGHT_WRIST]
        
        # Extract the face keypoints
        for idx in face_keypoint_indices:
            if idx == 1:
                keypoints.append([float(nose.x/height_width_ratio),float(nose.y/height_width_ratio),float(nose.z/height_width_ratio), idx])
            keyp = face_landmarks[idx]
            keypoints.append([float((keyp.x - nose.x)/height_width_ratio), float((keyp.y - nose.y)/height_width_ratio),float((keyp.z - nose.z)/height_width_ratio),idx])
        # Extract the hand landmarks (if present)
        if hands_results.multi_hand_landmarks:
            for idx, hand_landmarks in enumerate(hands_results.multi_hand_landmarks):
                hand_type = hands_results.multi_handedness[idx].classification[0].label
                if hand_type == "Left":
                    left_hand_keypoints = [[float((lm.x-left_wrist.x)/height_width_ratio), float((lm.y-left_wrist.y)/height_width_ratio),float((lm.z - left_wrist.z)/height_width_ratio),index] for index,lm in enumerate(hand_landmarks.landmark)]
                elif hand_type == "Right":
                    right_hand_keypoints = [[float((lm.x-right_wrist.x)/height_width_ratio), float((lm.y-right_wrist.y)/height_width_ratio),float((lm.z - right_wrist.z)/height_width_ratio),index] for index,lm in enumerate(hand_landmarks.landmark)]
    
    # Save the keypoints of the face, if there are no keypoints, add null coordinates (0,0,0) for each keypoint
    face_keypoint=[]
    if len(keypoints) == 0:
        for idx in face_keypoint_indices:
            face_keypoint.append([0, 0,0])
    else:
        keyp_found=False
        for idx in face_keypoint_indices:
            for keypoint in keypoints:
                if keypoint[3] == idx:
                    face_keypoint.append(keypoint[0:3])
                    keyp_found=True
                    break
            if not keyp_found:
                face_keypoint.append([0, 0, 0])

    # Flatten the face keypoints    
    face_keypoints_flat = np.array(
        face_keypoint,dtype='float32'
    ).ravel()  

    # Save the left and right hand keypoints, if there are no keypoints, add null coordinates (0,0,0) for each keypoint
    left_hand=[]
    right_hand=[]
    if len(left_hand_keypoints) == 0:
        for idx in hand_keypoint_indices:
            left_hand.append([0, 0,0])
    else:
        keyp_found=False
        for idx in hand_keypoint_indices:
            for keypoint in left_hand_keypoints:
                if keypoint[3] == idx:
                    left_hand.append(keypoint[0:3])
                    keyp_found=True
                    break
            if not keyp_found:
                left_hand.append([0, 0,0])

    if len(right_hand_keypoints) == 0:
        for idx in hand_keypoint_indices:
            right_hand.append([0, 0,0])
    else:
        keyp_found=False
        for idx in hand_keypoint_indices:
            for keypoint in right_hand_keypoints:
                if keypoint[3] == idx:
                    right_hand.append(keypoint[0:3])
                    keyp_found=True
                    break
            if not keyp_found:
                right_hand.append([0, 0, 0])
    
    # Flatten the hand keypoints
    left_hand_flat = np.array(
        left_hand,dtype='float32'
    ).ravel()

    right_hand_flat  = np.array(
        right_hand,dtype='float32'
    ).ravel()
    
    # Extract distances
    mouth_polseSX_dist = 0
    mouth_polseDX_dist = 0
    lip_up_down_dist = 0
    mouth_left_right_dist = 0
    dist_nose_mouth_left = 0
    dist_nose_mouth_right = 0
    nose_polseSX_dist = 0
    nose_polseDX_dist = 0
    dist_nose_mouth_left2 = 0
    dist_nose_mouth_right2 = 0
    dist_mouth_eye_center = 0
    left_wrist = None
    right_wrist = None
    
    if pose_results.pose_landmarks:
        # Get wrist landmarks (from Pose landmarks)
        left_wrist = pose_results.pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.LEFT_WRIST]
        left_wrist_point = np.array([left_wrist.x, left_wrist.y, left_wrist.z])
        right_wrist = pose_results.pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.RIGHT_WRIST]
        right_wrist_point = np.array([right_wrist.x, right_wrist.y, right_wrist.z])
        if face_results.multi_face_landmarks:
            face_landmarks = face_results.multi_face_landmarks[0]
            mouth_x = (face_landmarks.landmark[13].x + face_landmarks.landmark[14].x) / 2
            mouth_y = (face_landmarks.landmark[13].y + face_landmarks.landmark[14].y) / 2
            mouth_z = (face_landmarks.landmark[13].z + face_landmarks.landmark[14].z) / 2
            mouth_point = np.array([mouth_x, mouth_y, mouth_z])
            nose_point = np.array([face_landmarks.landmark[1].x , face_landmarks.landmark[1].y , face_landmarks.landmark[1].z ])

            # Distance between the mouth and wrists
            mouth_polseSX_dist = np.linalg.norm(left_wrist_point - mouth_point)
            mouth_polseDX_dist = np.linalg.norm(right_wrist_point - mouth_point)

            # Distance between upper and lower lip
            lip_up = np.array([face_landmarks.landmark[13].x, face_landmarks.landmark[13].y, face_landmarks.landmark[13].z])
            lip_down = np.array([face_landmarks.landmark[14].x, face_landmarks.landmark[14].y, face_landmarks.landmark[14].z])
            lip_up_down_dist = np.linalg.norm(lip_up - lip_down)

            # Distance between the left and right corners of the mouth
            mouth_left = np.array([face_landmarks.landmark[78].x, face_landmarks.landmark[78].y, face_landmarks.landmark[78].z])
            mouth_right = np.array([face_landmarks.landmark[308].x, face_landmarks.landmark[308].y, face_landmarks.landmark[308].z])

            # Distance between the nose and the corners of the mouth
            dist_nose_mouth_left = np.linalg.norm(nose_point - mouth_left)
            dist_nose_mouth_right = np.linalg.norm(nose_point - mouth_right)
            
            # Distance between the nose and the wrists
            nose_polseSX_dist = np.linalg.norm(left_wrist_point - nose_point)
            nose_polseDX_dist = np.linalg.norm(right_wrist_point - nose_point)
            
            # Set a specific point for the corners of the mouth (left and right)    
            mouth_left2 = np.array([face_landmarks.landmark[61].x, face_landmarks.landmark[61].y, face_landmarks.landmark[61].z])
            mouth_right2 = np.array([face_landmarks.landmark[291].x, face_landmarks.landmark[291].y, face_landmarks.landmark[291].z])

            # Distance between the nose and the specific corners of the mouth (left and right)
            dist_nose_mouth_left2 = np.linalg.norm(nose_point - mouth_left2)
            dist_nose_mouth_right2 = np.linalg.norm(nose_point - mouth_right2)

            # Distance between the specific corners of the mouth (left and right)
            mouth_left_right_dist = np.linalg.norm(mouth_left2 - mouth_right2)

            # Set a specific point for the eyes (left and right)
            left_eye2 = np.array([face_landmarks.landmark[133].x , face_landmarks.landmark[133].y , face_landmarks.landmark[133].z ])
            right_eye2 = np.array([face_landmarks.landmark[362].x , face_landmarks.landmark[362].y , face_landmarks.landmark[362].z])

            # Distance vertical between the center of the eyes and the center of the mouth
            center_eye = np.array((left_eye2 + right_eye2)/2)
            mouth_center = np.array((mouth_left2 + mouth_right2)/2)
            dist_mouth_eye_center = np.linalg.norm(mouth_center - center_eye)

    # Save the distances in a numpy array
    distances= np.array([mouth_polseSX_dist, mouth_polseDX_dist, lip_up_down_dist, 
                         mouth_left_right_dist,dist_nose_mouth_left,dist_nose_mouth_right,
                         nose_polseSX_dist,nose_polseDX_dist,dist_nose_mouth_left2,dist_nose_mouth_right2,
                         dist_mouth_eye_center],dtype='float32').ravel()

    left_wrist = None
    right_wrist = None
    if pose_results.pose_landmarks:
        # Get wrist landmarks (from Pose landmarks)
        left_wrist = pose_results.pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.LEFT_WRIST]
        right_wrist = pose_results.pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.RIGHT_WRIST]
    if height_width_ratio != 0:
        left_wrist = [float(left_wrist.x/height_width_ratio), float(left_wrist.y/height_width_ratio),float(left_wrist.z/height_width_ratio)] if left_wrist else [0, 0, 0] 
        right_wrist = [float(right_wrist.x/height_width_ratio), float(right_wrist.y/height_width_ratio),float(right_wrist.z/height_width_ratio)] if right_wrist else [0, 0, 0]
    else:
        left_wrist = np.array([left_wrist.x, left_wrist.y, left_wrist.z] if left_wrist else [0, 0,0],dtype='float32').ravel()
        right_wrist = np.array([right_wrist.x, right_wrist.y, right_wrist.z] if right_wrist else [0, 0,0],dtype='float32').ravel()
        
    
    # Save the keypoints and distances extracted
    combined_data = np.concatenate([
        face_keypoints_flat,
        left_hand_flat,
        right_hand_flat,
        left_wrist,
        right_wrist,
        distances
    ])
    return np.array(combined_data)

# Function to predict the action using the trained model
def predict_action(sequence):
    sequence = np.expand_dims(sequence, axis=0)
    prediction = model.predict(sequence)
    action_probabilities = prediction[0]
    predicted_class = np.argmax(action_probabilities)
    actions = ['food_to_mouth', 'drink_to_mouth','speech','other'] 
    return actions[predicted_class]

# List of keypoint indices for face landmarks
face_keypoint_indices = [1, 159, 386, 78, 95, 88, 178, 87, 14, 317, 402, 318, 324, 308, 191, 80, 81, 82, 13, 312, 311, 310, 415,
                         474, 475, 476, 477, 469, 470, 471, 472, 33, 133, 362, 61, 199, 263, 291]

MIN_DETECTION_CONFIDENCE = 0.5 
MIN_TRACKING_CONFIDENCE = 0.5 
window_size = 21 #TODO: Change in base of the sequence length of the model

# # Initialize MediaPipe solutions for face mesh, hands and pose
face_mesh = mp.solutions.face_mesh.FaceMesh(refine_landmarks=True, min_detection_confidence=MIN_DETECTION_CONFIDENCE, min_tracking_confidence=MIN_TRACKING_CONFIDENCE)
hands = mp.solutions.hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=MIN_DETECTION_CONFIDENCE)
pose = mp.solutions.pose.Pose(static_image_mode=False, min_detection_confidence=MIN_DETECTION_CONFIDENCE, min_tracking_confidence=MIN_TRACKING_CONFIDENCE)
sequence = []
video_path = "video3_dXR.avi" 
# Open webcam/video 
# cap = cv2.VideoCapture(0)  # Webcam
cap = cv2.VideoCapture(video_path) # Video file

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    face_results = face_mesh.process(rgb_frame)
    hands_results = hands.process(rgb_frame)
    pose_results = pose.process(rgb_frame)
    
    # Extract keypoints from face, hands and pose
    keypoints = extract_keypoints(face_results, hands_results, pose_results)

    #Optional: Draw the keypoints used for the prediction on the frame
    if keypoints is not None:    
        # Draw the face landmarks on the frame
        if face_results.multi_face_landmarks:
            landmarks = face_results.multi_face_landmarks[0].landmark
            for idx in face_keypoint_indices:
                landmark = landmarks[idx]
                x = int(landmark.x * frame.shape[1])
                y = int(landmark.y * frame.shape[0])
                cv2.circle(frame, (x, y), 2, (0, 255, 0), -1)  # Cerchio verde
                
                    
        # Draw the hand landmarks on the frame
        if hands_results.multi_hand_landmarks:
            for idx, hand_landmarks in enumerate(hands_results.multi_hand_landmarks):
                for landmark in hand_landmarks.landmark:
                    x = int(landmark.x * frame.shape[1])
                    y = int(landmark.y * frame.shape[0])
                    cv2.circle(frame, (x, y), 2, (255, 0, 0), -1)

        if pose_results.pose_landmarks:
            # Draw the pose landmarks on the frame
            left_wrist = pose_results.pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.LEFT_WRIST]
            left_wrist_point = (int(left_wrist.x * frame.shape[1]), int(left_wrist.y * frame.shape[0]))
            right_wrist = pose_results.pose_landmarks.landmark[mp.solutions.pose.PoseLandmark.RIGHT_WRIST]
            right_wrist_point = (int(right_wrist.x * frame.shape[1]), int(right_wrist.y * frame.shape[0]))
            cv2.circle(frame, left_wrist_point, 2, (255, 0, 0), -1)
            cv2.circle(frame, right_wrist_point, 2, (255, 0, 0), -1)

    # Predict the action using the model
    if keypoints is not None:
        sequence.append(keypoints)
        
        # Limit the sequence length to the specified length
        if len(sequence) > window_size:
            sequence.pop(0)

        # Predict the action when the sequence is complete
        if len(sequence) == window_size:
            action = predict_action(sequence)
            action_text = f"Azione predetta: {action}"
            cv2.putText(frame, action_text, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
    # Display the video
    cv2.imshow('Output', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'): # Press q to exit
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
